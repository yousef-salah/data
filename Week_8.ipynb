# %% [markdown]
# # dictionary
#
# - we can index the value by any user-defined key.
# - is key:value

# %%
my_dict = {} 
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
print(my_dict)
# Out:
# {}

# %%
# define a dictionary for stuents and their ids
students = {12312:"Ahmed",
            9808:"Sami"}

print(students)
# Out:
# {12312: 'Ahmed', 9808: 'Sami'}

# %%
# to access a value I need to provide the key to the dicitonary
print(students[9808])
# Out:
# Sami

# %%
print(students.get(6754))
# Out:
# None

# %%
# add a new key:value to the dictionary
students[6754] = 'Raghad'
print(students)
# Out:
# {12312: 'Ahmed', 9808: 'Sami', 6754: 'Raghad'}

# %%
# update a value
students[9808] = 'Mohammed'
print(students)
# Out:
# {12312: 'Ahmed', 9808: 'Mohammed', 6754: 'Raghad'}

# %%
students[1010] = ['Sami', 'Abdelrahman', 'Ayas']
print(students)
# Out:
# {12312: 'Ahmed', 9808: 'Mohammed', 6754: 'Raghad', 1010: ['Sami', 'Abdelrahman', 'Ayas']}

# %%
students[1010] = {'Sami': 21312, 'Ayas': 3132}
print(students)
# Out:
# {12312: 'Ahmed', 9808: 'Mohammed', 6754: 'Raghad', 1010: {'Sami': 21312, 'Ayas': 3132}}

# %%
print(type(students[1010]))
# Out:
# <class 'dict'>

# %%
# get the list of all keys from a dict
student_keys = students.keys()
print(student_keys)
# Out:
# dict_keys([12312, 9808, 6754, 1010])

# %%
# use for loop to iterate through a dictionary
for one_student_key in students.keys():
  print(one_student_key, students[one_student_key])
# Out:
# 12312 Ahmed
# 9808 Mohammed
# 6754 Raghad
# 1010 {'Sami': 21312, 'Ayas': 3132}

# %%
# use the values function
students_values = students.values()
print(students_values)
# Out:
# dict_values(['Ahmed', 'Mohammed', 'Raghad', {'Sami': 21312, 'Ayas': 3132}])

# %%
# use th items function
student_items = students.items()
print(student_items)
# Out:
# dict_items([(12312, 'Ahmed'), (9808, 'Mohammed'), (6754, 'Raghad'), (1010, {'Sami': 21312, 'Ayas': 3132})])

# %%
# use items with for loop
for key, value in students.items():
  print(key, value)
# Out:
# 12312 Ahmed
# 9808 Mohammed
# 6754 Raghad
# 1010 {'Sami': 21312, 'Ayas': 3132}

# %%
# remove a key:value with a specific key
# pop will return the removed value
removed_value = students.pop(9808)

# %%
students
# Out:
# {1010: {'Ayas': 3132, 'Sami': 21312}, 6754: 'Raghad', 12312: 'Ahmed'}

# %%
removed_value
# Out:
# 'Mohammed'

# %%
# remove an arbitrary key:value
# return both the key and the value
removed_key_value = students.popitem()

# %%
removed_key_value
# Out:
# (1010, {'Ayas': 3132, 'Sami': 21312})

# %%
students
# Out:
# {6754: 'Raghad', 12312: 'Ahmed'}

# %%
students
# Out:
# {9808: 'Sami', 12312: 'Ahmed'}

# %%
if 9808 in students:
  print('found')
# Out:
# found

# %%
# write a function that return a dictory with the probability of randomly selecting 
# any element of the sample space
# return type is a dictory, key is the element, the value is the probability
def compute_probability(sample_space):

  # compute the sample space size
  sample_space_size = len(sample_space)

  # get all unique values from the sample space
  element_statistics = {}

  # for every value compute its count
  for element in sample_space:
    if element in element_statistics:
      element_statistics[element] += 1

    else:
      element_statistics[element] = 1


  # compute probability
  for key in element_statistics.keys():
    element_statistics[key] = element_statistics[key] / sample_space_size

  return element_statistics

# %%
students = [19,19,18,20,20,20,18]
result = compute_probability(students)

# %%
result
# Out:
# {18: 0.2857142857142857, 19: 0.2857142857142857, 20: 0.42857142857142855}

# %% [markdown]
# # mutable immutable data in Python
# - mutable data: variables data structure that we can update/change its value
# - immutable data: variables, data structure that we cannot update/change its value

# %%
# id(): is a built in function that returns the id of the variable.
x = 205023
print(id(x))
# Out:
# 139933254841424

# %%
y = 98341242
print(id(y))
# Out:
# 139933255724080

# %%
# == : compare the values
# is: compare if the two variables have the same id

x = 1231234
y = 1231234

print( x == y)
# Out:
# True

# %%
print(x is y)
# Out:
# False

# %%
print('x ', id(x))
print('y ', id(y))
# Out:
# x  139933254840592
# y  139933254841392

# %%
x = 1231234
print(x , id(x))

x = 1023112212
print(x, id(x))
# Out:
# 1231234 139933254842096
# 1023112212 139933254842352

# %%
my_list = [1,2,3]
print(id(my_list))

my_list.append(4)
print(id(my_list))

my_list[-1] = 100
print(id(my_list))
print(my_list)
# Out:
# 139933254550944
# 139933254550944
# 139933254550944
# [1, 2, 3, 100]

# %%
x = 13123123
y = x

print(id(x))
print(id(y))
print(x is y)
# Out:
# 139933254840592
# 139933254840592
# True

# %%
x = 123123
y = 123123

print(x is y)
# Out:
# False

# %%
list1 = [1,2,3]
list2 = [1,2,3]
print(list1 is list2)
# Out:
# False

# %%
list1 = [1,2,3]
list2 = list1
print(list1 is list2)
# Out:
# True

# %%
list1.append(305)
print(list2)
# Out:
# [1, 2, 3, 305]

# %%
x = True
print(id(x))
x = False
print(id(y))
# Out:
# 94303039279360
# 139933254842704

# %%
x = (1,2)
print(id(x))

x = (1,2)
print(id(x))
# Out:
# 139933255206144
# 139933255038608

# %%
def get_some_data(list1):

  print('id of the list inside the function ', id(list1))
  list1.append(305)

# %%
test_list = [1,2]
print('id of the list before calling ', id(test_list))

# call the function
get_some_data(test_list)

print('id of the list after calling ', id(test_list))

print('list after calling  ', test_list)
# Out:
# id of the list before calling  139933254466528
# id of the list inside the function  139933254466528
# id of the list after calling  139933254466528
# list after calling   [1, 2, 305]

# %%
def get_some_data(list1):

  list1 = []
  print('id of the list inside the function ', id(list1))
  list1.append(305)

# %%
test_list = [1,2]
print('id of the list before calling ', id(test_list))

# call the function
get_some_data(test_list)

print('id of the list after calling ', id(test_list))

print('list after calling  ', test_list)
# Out:
# id of the list before calling  139933255017808
# id of the list inside the function  139933254466528
# id of the list after calling  139933255017808
# list after calling   [1, 2]

# %%
def get_some_data(int_data):
  int_data = 231234132
  print('id of the integer inside the function ', id(int_data))

# %%
x = 1234213412
print('id of the integer before calling ', id(x))

get_some_data(x)

print('id of the integer after calling ', id(x))
print(x)
# Out:
# id of the integer before calling  139933254842096
# id of the integer inside the function  139933254843856
# id of the integer after calling  139933254842096
# 1234213412

# %%
# small numbers in python and object ids

x = 12312312
y = 12312312
print(id(x))
print(id(y))
print(x is y)
# Out:
# 139933254436464
# 139933254437360
# False

# %%
# small numbers in python and object ids

x = 4
y = 4
print(id(x))
print(id(y))
print(x is y)
# Out:
# 94303039953504
# 94303039953504
# True

# %%
z = 4
print(id(z))
# Out:
# 94303039953504

# %% [markdown]
# # strings in python

# %%
name = 'Ahmad'
print(name)
# Out:
# Ahmad

# %%
name = "Ahmad"
print(name)
# Out:
# Ahmad

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
# to get number of characters in a string
# I use the len() function

print(len(name))
# Out:
# 5

# %%
# to get the first and the last charactor in a string
print(name[0], name[-1])
# Out:
# A d

# %%
# "Sami"

name = '"Sami"'
print(name)

# 'Sami'
name = "'Sami'"
print(name)
# Out:
# "Sami"
# 'Sami'

# %%
# test if a substring exist in another string

sentence = "Welcome to the course"
if "to" in sentence:
  print('found')
# Out:
# found

# %%
print(id(sentence))
# Out:
# 140079076113024

# %%
sentence = sentence + " python"
print(sentence)
# Out:
# Welcome to the course python

# %%
print(id(sentence))
# Out:
# 140079075582320

# %% [markdown]
# # for and while loops

# %%
students = [12,12,32,4]
for one_student in students:
  print(one_student)
# Out:
# 12
# 12
# 32
# 4

# %%
# while loop

index = 0
marks = [12,40,50,70,12]

while index < len(marks):

  if marks[index] >= 60:
    break

  print(marks[index])
  index += 1
# Out:
# 12
# 40
# 50

# %% [markdown]
# ### range and for loop

# %%
for index in range(5):
  print(index)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for index in range(3, 5):
  print(index)
# Out:
# 3
# 4

# %%
for index in range(3, 8, 2):
  print(index)
# Out:
# 3
# 5
# 7

# %%
marks = [12,40,50,70,12]

for index in range(len(marks)):
  print(index, marks[index])
# Out:
# 0 12
# 1 40
# 2 50
# 3 70
# 4 12

# %%
for one_mark in marks:
  print(one_mark)
# Out:
# 12
# 40
# 50
# 70
# 12

# %% [markdown]
# # lambda functions
# - map, filter with respect to list in python

# %%
def add_two_numbers(x, y):
  return x+y

print(add_two_numbers(4,7))
# Out:
# 11

# %%
my_fun = lambda x,y: x+y 

print(my_fun(4,7))
# Out:
# 11

# %%
marks = [20,40,50,10]

for index in range(len(marks)):
  marks[index] += 3

print(marks)
# Out:
# [23, 43, 53, 13]

# %%
marks = [20,40,50,10]
restuls = map(lambda x: x+3,  marks)
restuls = list(restuls)

# %%
restuls
# Out:
# [23, 43, 53, 13]

# %%
marks = [60,40,50,80]
restuls = filter(lambda x: x >= 60,  marks)
restuls = list(restuls)

# %%
restuls
# Out:
# [60, 80]

# %%
marks = [60,40,50,80]
results = []

for one_mark in marks:
  if one_mark >= 60:
    results.append(one_mark)

print(results)
# Out:
# [60, 80]

# %%
#marks = [20,40,50,10]
#restuls = map(lambda x: x+3,  marks)
#restuls = list(restuls)

marks = [20,40,50,10]

def add_three_marks(x):
  return x + 3

results = []
for one_mark in marks:
  results.append(add_three_marks(one_mark))

print(results)
# Out:
# [23, 43, 53, 13]

# %% [markdown]
# # reading data from a file

# %%
# uploud a file form my laptop
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e454e1c-3edc-4f12-8d3b-7ea69ab0e64f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e454e1c-3edc-4f12-8d3b-7ea69ab0e64f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sportsci_3_1.txt to sportsci_3_1.txt

# %%
# read data from a file
f = open("sportsci_3_1.txt")
# read the content to a variable
data = f.read()
data
# Out:
# "%0 Journal Article\n%9 Editorial\n%A Hopkins, W.G.\n%T Sportscience sets the pace for publishing sport research\n%J Sportsci\n%B Sportscience\n%V 3\n%N 1\n%P sportsci.org/jour/9901/wghedit.html (721 words)\n%D 1999\n%O Department of Physiology and School of Physical Education, University of \nOtago, Dunedin 9001, New Zealand. Email: will.hopkins=AT=otago.ac.nz\n%X Sportscience, a new quarterly journal, offers many innovative features: new \nstructures for articles, comprehensible data and statistics, sections devoted to \npopular content through formal research papers, and downloadable article \ntemplates, reprints, and bibliographic files.\n%K journal, peer-review, sport science, Web\n\n%0 Journal Article\n%9 News\n%A Sands, W.A.\n%A McNeil, J.R.\n%T Judging gymnastics with biomechanics\n%J Sportsci\n%B Sportscience\n%V 3\n%N 1\n%P sportsci.org/jour/9901/was.html (865 words)\n%D 1999\n%O Department of Exercise & Sport Science, University of Utah, Salt Lake City, \nUtah 84112.  Email: wmasands=AT=concentric.net\n%X Human judges often have difficulty in determining the subtle differences in \ntrajectories and speed between competitors in gymnastics. We have devised an \nobjective scoring system for the compulsory vault by using video digitizing, \ninfrared timers, and a computer algorithm. We combined the objective score with \na human judge's score for form errors. The objective score successfully \nincreased the differentiation between performances in a trial of 25 gymnasts at \na competition.\n%K competitive performance, judge, score, skill, vault\n\n%0 Journal Article\n%9 News\n%A Hopkins, W.G.\n%A Hawley, J.A.\n%A Burke, L.M.\n%T Researching worthwhile performance enhancements\n%J Sportsci\n%B Sportscience\n%V 3\n%N 1\n%P sportsci.org/jour/9901/wghnews.html (1101 words)\n%D 1999\n%O Department of Physiology, University of Otago, Dunedin 9001, New Zealand. \nEmail: will.hopkins=AT=otago.ac.nz\n%O Department of Human Biology & Movement Science, RMIT University, Bundoora \n3083, Australia\n%O Department of Sports Nutrition, Australian Institute of Sport, Belconnen \n2616, Australia\n%X For an athlete at the top of the field, a performance enhancement makes a \ndifference to the chance of winning when it is about half the athlete's typical \nbetween-event variation in performance.  Measuring enhancements of this \nmagnitude with adequate precision requires much bigger sample sizes than \nresearchers normally use.  To avoid confusion over interpretation of their \nfindings, researchers should therefore publish and explain the precision of \ntheir estimates of performance enhancement.\n%K competitions, elite athletes, exercise tests, research design and analysis\n\n%0 Journal Article\n%9 News\n%A Hatfield, F.C.\n%T A new weights machine with dynamically adjustable resistance\n%J Sportsci\n%B Sportscience\n%V 3\n%N 1\n%P sportsci.org/jour/9901/fch.html (762 words)\n%D 1999\n%O International Sports Sciences Association, Santa Barbara, California 93101. \nEmail: drsquat=AT=issaonline.com\n%X A new strength-training machine allows the user to instantly change \nresistance at any point in the exercise movement. The machine has the potential \nto improve strength by optimizing the time each targeted muscle spends under \nmaximum stress. Whether it is more effective than other machines or free weights \nremains to be seen.\n%K gym equipment, strength training\n\n%0 Journal Article\n%9 News\n%A Nicholson, R.M.\n%T The power clean vs the power pull for strength training\n%J Sportsci\n%B Sportscience\n%V 3\n%N 1\n%P sportsci.org/jour/9901/rmn.html (768 words)\n%D 1999\n%O School of Physical Education, University of Otago, Dunedin 9001, New Zealand. \nEmail: rnicholson=AT=pooka.otago.ac.nz\n%X In a recent discussion on the Sportscience Forum contributors agreed that \npower cleans and power pulls are effective ways to develop power.  They also \nagreed that the stages involved in each lift need to be taught progressively, \nthrough a full ...

# %%
sentence = "Welcome to Python Course and Prob"
result = sentence.split()
result
# Out:
# ['Welcome', 'to', 'Python', 'Course', 'and', 'Prob']

# %% [markdown]
# # we would like to predict the next word when typing something.
# - autocomplete

# %%
# split the data into different words
words = data.split()

# %%
# get the first 100 words
words[0:100]
# Out:
# ['%0',
#  'Journal',
#  'Article',
#  '%9',
#  'Editorial',
#  '%A',
#  'Hopkins,',
#  'W.G.',
#  '%T',
#  'Sportscience',
#  'sets',
#  'the',
#  'pace',
#  'for',
#  'publishing',
#  'sport',
#  'research',
#  '%J',
#  'Sportsci',
#  '%B',
#  'Sportscience',
#  '%V',
#  '3',
#  '%N',
#  '1',
#  '%P',
#  'sportsci.org/jour/9901/wghedit.html',
#  '(721',
#  'words)',
#  '%D',
#  '1999',
#  '%O',
#  'Department',
#  'of',
#  'Physiology',
#  'and',
#  'School',
#  'of',
#  'Physical',
#  'Education,',
#  'University',
#  'of',
#  'Otago,',
#  'Dunedin',
#  '9001,',
#  'New',
#  'Zealand.',
#  'Email:',
#  'will.hopkins=AT=otago.ac.nz',
#  '%X',
#  'Sportscience,',
#  'a',
#  'new',
#  'quarterly',
#  'journal,',
#  'offers',
#  'many',
#  'innovative',
#  'features:',
#  'new',
#  'structures',
#  'for',
#  'articles,',
#  'comprehensible',
#  'data',
#  'and',
#  'statistics,',
#  'sections',
#  'devoted',
#  'to',
#  'popular',
#  'content',
#  'through',
#  'formal',
#  'research',
#  'papers,',
#  'and',
#  'downloadable',
#  'article',
#  'templates,',
#  'reprints,',
#  'and',
#  'bibliographic',
#  'files.',
#  '%K',
#  'journal,',
#  'peer-review,',
#  'sport',
#  'science,',
#  'Web',
#  '%0',
#  'Journal',
#  'Article',
#  '%9',
#  'News',
#  '%A',
#  'Sands,',
#  'W.A.',
#  '%A',
#  'McNeil,']

# %%
{"new": 3,
 "journal": 7,
 }

# %%
memory = {}

# %%
memory["ahmad"] = 1
memory
# Out:
# {'ahmad': 1}

# %%
'ahmad' in memory
# Out:
# True

# %%
if 'ahmad' in memory:
  memory['ahmad'] += 1

# %%
memory
# Out:
# {'ahmad': 2}

# %%
memory = {}

for one_word in words:
  if one_word in memory:
    memory[one_word] += 1
  else:
    memory[one_word] = 1

memory
# Out:
# {'%0': 13,
#  '%9': 13,
#  '%A': 16,
#  '%B': 13,
#  '%D': 13,
#  '%J': 13,
#  '%K': 13,
#  '%N': 13,
#  '%O': 15,
#  '%P': 13,
#  '%T': 13,
#  '%V': 13,
#  '%X': 12,
#  '&': 4,
#  '(1101': 1,
#  '(1559': 1,
#  '(1733': 1,
#  '(1805': 1,
#  '(1844-1907)': 1,
#  '(2618': 1,
#  '(4397': 1,
#  '(5579': 1,
#  '(721': 1,
#  '(762': 1,
#  '(768': 1,
#  '(865': 1,
#  '(HMB).': 1,
#  '(e.g.,': 1,
#  '(hang': 1,
#  '(leucine,': 1,
#  '01003.': 1,
#  '1': 13,
#  '10': 1,
#  '19': 1,
#  '1999': 13,
#  '23': 1,
#  '25': 1,
#  '2616,': 2,
#  '2W5.': 1,
#  '3': 13,
#  '300': 2,
#  '3083,': 1,
#  '31': 1,
#  '38152.': 1,
#  '52557.': 1,
#  '61': 1,
#  '84112.': 1,
#  '9001,': 3,
#  '9001.': 3,
#  '93101.': 1,
#  'A': 3,
#  'AIM.': 1,
#  'ANALYSES.': 1,
#  'All': 1,
#  'American': 1,
#  'Amherst,': 1,
#  'Antigonish,': 1,
#  'Article': 13,
#  'Association,': 1,
#  'Association.': 1,
#  'Atwater': 1,
#  'Australia': 2,
#  'Australia.': 1,
#  'Australian': 2,
#  'B2G': 1,
#  'BACKGROUND.': 3,
#  'BCAA,': 1,
#  'Barbara,': 1,
#  'Be': 2,
#  'Belconnen': 2,
#  'Biology': 2,
#  'Branched-chain': 1,
#  'Bundoora': 1,
#  'Burke,': 2,
#  'CONCLUSIONS.': 3,
#  'California': 1,
#  'Canada': 1,
#  'City,': 1,
#  'Cross-sectional,': 1,
#  'DESIGN.': 1,
#  'Daley,': 1,
#  'DeMont,': 1,
#  'Department': 12,
#  'Department,': 1,
#  'Describe': 2,
#  'Dietary': 1,
#  'Dunedin': 3,
#  'Dunedin,': 3,
#  'Editorial': 1,
#  'Education,': 6,
#  'Effects': 1,
#  'Email:': 13,
#  'Exercise': 4,
#  'F.C.': 1,
#  'F.I.': 1,
#  'FINDINGS.': 2,
#  'FURTHER': 2,
#  'Fairfield,': 1,
#  'Fluid': 1,
#  'For': 2,
#  'Forum': 1,
#  'Francis': 1,
#  'Give': 1,
#  'Guidelines': 1,
#  'HMB,': 1,
#  'Hatfield,': 1,
#  'Hawley,': 1,
#  'History': 1,
#  'Hopkins,': 5,
#  'How': 2,
#  'However,': 1,
#  'Human': 3,
#  'I': 2,
#  'In': 5,
#  'Include': 1,
#  'Indicate': 1,
#  'Ingesting': 1,
#  'Institute': 2,
#  'International': 1,
#  'Internet,': 1,
#  'Interpret': 1,
#  'Iowa,': 1,
#  'J.A.': 1,
#  'J.R.': 1,
#  'Journal': 13,
#  'Judging': 1,
#  'K.': 1,
#  'Katch,': 1,
#  'Kreider,': 1,
#  'L.M.': 2,
#  'LITERATURE.': 2,
#  'Laboratory,': 1,
#  'Lake': 1,
#  'Learn': 1,
#  'List': 2,
#  'M.E.': 1,
#  'MEASURES.': 1,
#  'Maharishi': 1,
#  'Makers:': 1,
#  'Management,': 1,
#  'Maryland,': 1,
#  'Massachusetts,': 1,
#  'McNeil,': 1,
#  'Measuring': 1,
#  'Memphis,': 2,
#  'Most': 1,
#  'Movement': 2,
#  'Moving': 1,
#  "Nature's": 1,
#  'New': 6,
#  'News': 5,
#  'Newsletter': 1,
#  'Nicholson,': 1,
#  'Nova': 1,
#  'Nutrition': 1,
#  'Nutrition,': 2,
#  'OUTCOMES.': 1,
#  'Of': 1,
#  'Olin': 1,
#  'Olympic': 1,
#  'Otago,': 6,
#  'Perspective': 6,
#  'Physical': 5,
#  'Physiology': 4,
#  'Physiology,': 1,
#  'Protein': 1,
#  'Psychological': 1,
#  'R.B.': 1,
#  'R.M.': 1,
#  'RESEARCH.': 2,
#  'RMIT': 1,
#  'Recent': 1,
#  'Researching': 1,
#  'Review': 1,
#  'SUBJECTS.': 1,
#  'Salt': 1,
#  'Sands,': 1,
#  'Santa': 1,
#  'School': 5,
#  'Science,': 3,
#  'Sciences': 2,
#  'Sciences,': 1,
#  'Scotia,': 1,
#  'Some': 1,
#  'Sport': 3,
#  'Sport,': 2,
#  'Sports': 3,
#  'Sportsci': 13,
#  'Sportscience': 15,
#  'Sportscience,': 1,
#  'St': 1,
#  'State': 2,
#  'Summary': 1,
#  'Summary,': 1,
#  'Supplementation': 1,
#  'TECHNICALITIES.': 1,
#  'Technology': 1,
#  'Tennessee': 1,
#  'The': 11,
#  'There': 1,
#  'These': 1,
#  'They': 1,
#  'This': 2,
#  'To': 2,
#  'Together:': 1,
#  'Topics': 1,
#  'Try': 1,
#  'Two': 2,
#  'USA': 2,
#  'University': 10,
#  'University,': 2,
#  'Until': 1,
#  'Use': 1,
#  'Utah': 1,
#  'Utah,': 1,
#  'W.A.': 1,
#  'W.G.': 5,
#  'We': 2,
#  'Web': 1,
#  'Whether': 2,
#  'Wilbur': 1,
#  'Write': 1,
#  'X': 2,
#  'Xavier': 1,
#  'Y,': 2,
#  'Zealand': 3,
#  'Zealand.': 3,
#  'a': 18,
#  'abbreviations': 1,
#  'abbreviations.': 1,
#  'about': 1,
#  'abstracts,': 1,
#  'accurately': 1,
#  'acids': 4,
#  'acids,': 3,
#  'adaptations': 2,
#  'additional': 1,
#  'adequate': 1,
#  'adjustable': 1,
#  'advice': 2,
#  'affects': 1,
#  'agreed': 2,
#  'air-water': 1,
#  'algorithm.': 1,
#  'allows': 1,
#  'also': 2,
#  'amino': 7,
#  'amino-acid': 1,
#  'among': 1,
#  'an': 5,
#  'anabolic': 3,
#  'anabolic,': 1,
#  'analysis': 1,
#  'analysis,': 2,
#  'and': 44,
#  'and/or': 1,
#  'animal': 1,
#  'animals': 2,
#  'any': 3,
#  'appears': 2,
#  'appropriate': 1,
#  'aquatic': 2,
#  'are': 8,
#  'arginine,': 1,
#  'argument': 1,
#  'arise': 1,
#  'article': 2,
#  'articles': 1,
#  'articles,': 3,
#  'as': 6,
#  'at': 4,
#  'athlete': 1,
#  "athlete's": 1,
#  'athlete.': 1,
#  'athletes': 3,
#  'athletes,': 1,
#  'athletes.': 4,
#  'athletic': 5,
#  'available': 1,
#  'avoid': 1,
#  'balance': 1,
#  'based': 1,
#  'be': 8,
#  'because': 1,
#  'benefit': 1,
#  'benefits': 1,
#  'better': 1,
#  'between': 5,
#  'between-event': 1,
#  'beyond': 1,
#  'bibliographic': 1,
#  'bigger': 1,
#  'biomechanics': 1,
#  'biomechanics,': 1,
#  'biomechanists': 1,
#  'book': 1,
#  'books,': 1,
#  'branched-chain': 2,
#  'but': 5,
#  'by': 8,
#  'caliber,': 1,
#  'calorimetry,': 1,
#  'can': 1,
#  'carbohydrate': 3,
#  'case-control,': 1,
#  'catabolism': 1,
#  'catabolism,': 1,
#  'central': 1,
#  'certain': 1,
#  'chance': 1,
#  'change': 1,
#  'changes': 1,
#  'chapters.': 1,
#  'citation': 1,
#  'clean': 3,
#  'clean,': 1,
#  'cleans': 1,
#  'clear.': 1,
#  'clinical': 1,
#  'combined': 1,
#  'common': 3,
#  'comparative': 1,
#  'competition.': 1,
#  'competitions,': 1,
#  'competitive': 4,
#  'competitors': 1,
#  'components': 1,
#  'comprehensible': 1,
#  'compromise': 2,
#  'compulsory': 1,
#  'computer': 1,
#  'conclusion': 1,
#  'conditions': 1,
#  'conferences,': 1,
#  'confusion': 1,
#  'considerably': 1,
#  'consist': 2,
#  'consistency': 1,
#  'consistent': 1,
#  'content': 1,
#  'continue': 1,
#  'contributes': 1,
#  'contributors': 1,
#  'controlled': 1,
#  'creates': 1,
#  'creatine': 2,
#  'creatine,': 2,
#  'data': 4,
#  'data,': 1,
#  'dead': 2,
#  'deal': 1,
#  'decide': 1,
#  'demographics.': 1,
#  'demonstrate': 1,
#  'dependent': 1,
#  'depth': 2,
#  'descriptive': 1,
#  'design': 1,
#  'design,': 3,
#  'determine': 1,
#  'determining': 1,
#  'develop': 1,
#  'deviations': 1,
#  'devised': 1,
#  'devoted': 1,
#  'differ': 1,
#  'difference': 1,
#  'differences': 3,
#  'differentiation': 1,
#  'difficulty': 1,
#  'digitizing,': 1,
#  'discussion': 1,
#  'do': 2,
#  'document.': 1,
#  'documents': 2,
#  'does': 1,
#  'dominant': 1,
#  'done.': 1,
#  'double-blind': 1,
#  'downloadable': 1,
#  'drag,': 1,
#  'drag.': 1,
#  'drinks,': 1,
#  'drsquat=AT=issaonline.com': 1,
#  'due': 2,
#  'during': 3,
#  'dynamically': 1,
#  'dynamics,': 2,
#  'each': 2,
#  'ease': 1,
#  'economical': 2,
#  'edemont=AT=juliet.stfx.ca': 1,
#  'education': 1,
#  'effect': 2,
#  'effective': 3,
#  'effects': 5,
#  'effects.': 2,
#  'elements': 1,
#  'elite': 1,
#  'emergency': 1,
#  'employing': 1,
#  'encyclopedia,': 1,
#  'endurance': 2,
#  'energy': 1,
#  'enhance': 2,
#  'enhancement': 1,
#  'enhancement.': 1,
#  'enhancements': 2,
#  'enhances': 2,
#  'environment.': 1,
#  'environmental': 1,
#  'equipment,': 1,
#  'equivocal': 1,
#  'ergogenic': 2,
#  'ergogenic,': 1,
#  'errors,': 1,
#  'errors.': 1,
#  'estimates': 1,
#  'evaluates': 1,
#  'evaluation': 1,
#  'event,': 1,
#  'evidence': 2,
#  'example': 1,
#  'example,': 1,
#  'example:': 1,
#  'examples': 1,
#  'exercise': 5,
#  'exercise-': 1,
#  'experience': 1,
#  'experience.': 1,
#  'explain': 2,
#  'explaining': 2,
#  'fat-free': 1,
#  'fatigue': 1,
#  'features:': 1,
#  'feeding': 1,
#  'field,': 1,
#  'files.': 1,
#  'findings': 1,
#  'findings,': 1,
#  'first': 2,
#  'five': 1,
#  'fkatch=AT=excsci.umass.edu': 1,
#  'flow': 1,
#  'fluid': 4,
#  'following': 1,
#  'for': 14,
#  'force,': 1,
#  'forces': 1,
#  'form': 1,
#  'formal': 1,
#  'four': 1,
#  'frame.': 1,
#  'free': 1,
#  'freestyle': 1,
#  'from': 5,
#  'full': 1,
#  'gains': 1,
#  'game': 2,
#  'games': 2,
#  'games,': 1,
#  'games:': 1,
#  'generalizing': 1,
#  'generally': 1,
#  'generates': 1,
#  'generating': 1,
#  'generation': 1,
#  'get': 1,
#  'give': 1,
#  'glide': 1,
#  'glucocorticoids,': 1,
#  'glutamine': 1,
#  'glutamine,': 2,
#  'glycogen': 1,
#  'grammar,': 1,
#  'grammar.': 2,
#  'grammatical': 1,
#  'greatest': 1,
#  'grounds': 1,
#  'growth': 1,
#  'guidelines': 1,
#  'gym': 1,
#  'gymnastics': 1,
#  'gymnastics.': 1,
#  'gymnasts': 1,
#  'half': 1,
#  'hang': 1,
#  'hard': 1,
#  'has': 3,
#  'have': 5,
#  'health-fitness...': 1,
#  'here': 2,
#  'high-intensity': 1,
#  'histidine,': 1,
#  'hormonal': 1,
#  'hormone,': 1,
#  'how': 2,
#  'human': 2,
#  'hydration': 1,
#  'hydroxymethylbutyrate': 2,
#  'hydroxymethylbutyrate,': 1,
#  'ideas': 1,
#  'if': 2,
#  'immune': 1,
#  'important': 1,
#  'important.': 2,
#  'improve': 1,
#  'in': 28,
#  'include': 1,
#  'included': 1,
#  'increase': 1,
#  'increased': 1,
#  'indicate': 1,
#  'individuals': 1,
#  'induced': 1,
#  'infrared': 1,
#  'initiating': 1,
#  'innovative': 1,
#  'insights': 1,
#  'instantly': 1,
#  'insulin,': 1,
#  'intake': 1,
#  'intense': 1,
#  'interest': 1,
#  'interface': 1,
#  'intermittent': 1,
#  'interpret': 1,
#  'interpretation': 1,
#  'intervention,': 1,
#  'investigations,': 1,
#  'involved': 3,
#  'is': 9,
#  'isoleucine,': 1,
#  'it': 3,
#  'journal,': 2,
#  "judge's": 1,
#  'judge,': 1,
#  'judges': 1,
#  'kdaley=AT=mum.edu': 1,
#  'kinesiology,': 1,
#  'kreider.richard=AT=coe.memphis.edu': 1,
#  'lab': 1,
#  'lack': 2,
#  'language': 1,
#  'lburke=AT=ausport.gov.au': 1,
#  'lecture': 1,
#  'less': 2,
#  'lesson': 1,
#  'lift': 2,
#  'lift)': 1,
#  'lift,': 2,
#  'likely': 1,
#  'limitations': 1,
#  'limited': 1,
#  'list': 1,
#  'literature': 1,
#  'little': 1,
#  'locomotion': 1,
#  'lysine,': 1,
#  'machine': 3,
#  'machines': 1,
#  'magnitude': 1,
#  'magnitudes': 1,
#  'main': 2,
#  'maintain': 1,
#  'major': 1,
#  'makes': 1,
#  'manuscript.': 1,
#  'many': 1,
#  'mass': 1,
#  'maximum': 1,
#  'may': 5,
#  'means': 1,
#  'measure': 2,
#  'measurement': 1,
#  'mechanisms': 2,
#  'medical': 1,
#  'metabolism': 1,
#  'methionine,': 1,
#  'methodological': 1,
#  'minimizes': 1,
#  'monograph,': 1,
#  'more': 4,
#  'most': 1,
#  'motion.': 1,
#  'motion;': 1,
#  'move': 1,
#  'movement': 1,
#  'movement.': 1,
#  'much': 1,
#  'muscle': 1,
#  'must': 2,
#  'nature': 1,
#  'necessary': 1,
#  'need': 4,
#  'needs': 1,
#  'new': 4,
#  'news,': 1,
#  'newsletter:': 1,
#  'nitrogen': 1,
#  'no': 1,
#  'normally': 1,
#  'not': 4,
#  'notes,': 1,
#  'now': 1,
#  'number': 2,
#  'nutrients': 1,
#  'nutrition,': 2,
#  'nutritional': 4,
#  'objective': 3,
#  'of': 73,
#  'offers': 1,
#  'often': 1,
#  'on': 14,
#  'on.': 2,
#  'one': 3,
#  'ongoing': 1,
#  'only': 3,
#  'optimal': 1,
#  'optimizing': 1,
#  'or': 13,
#  'original': 1,
#  'ornithine,': 1,
#  'other': 2,
#  'outcomes': 2,
#  'outline': 1,
#  'over': 1,
#  'pace': 1,
#  'paper': 1,
#  'papers,': 1,
#  'peer-review,': 1,
#  'performance': 9,
#  'performance,': 2,
#  'performance.': 4,
#  'performances': 1,
#  'phase': 1,
#  'phenylalanine)': 1,
#  'physical': 1,
#  'plain': 1,
#  'plans,': 1,
#  'play': 1,
#  'point': 1,
#  'popular': 2,
#  'populations.': 1,
#  'possible,': 2,
#  'potential': 3,
#  'power': 7,
#  'power.': 1,
#  'practical': 1,
#  'precision': 3,
#  'preferred': 1,
#  'present': 1,
#  'present.': 1,
#  'presentation': 1,
#  'presentation,': 1,
#  'prior': 1,
#  'probably': 1,
#  'problems': 1,
#  'procedures': 1,
#  'progressively,': 1,
#  'promote': 2,
#  'promoted': 1,
#  'protein': 3,
#  'protein,': 1,
#  'provide': 1,
#  'publications.': 1,
#  'publish': 1,
#  'published': 1,
#  'publishing': 1,
#  'publishing,': 3,
#  'pull': 2,
#  'pulls': 1,
#  'punctuation': 1,
#  'punctuation,': 1,
#  'purported': 1,
#  'qualitatively,': 1,
#  'quantitatively,': 1,
#  'quarterly': 1,
#  'randomized': 1,
#  'range': 1,
#  'ranges': 1,
#  'ranging': 1,
#  'rationale': 1,
#  "reader's": 1,
#  'real': 2,
#  'recent': 1,
#  'recommendations': 1,
#  'reduce': 2,
#  'reevaluated.': 1,
#  'regard': 1,
#  'relationship': 1,
#  'release': 1,
#  'relevant': 1,
#  'remains': 1,
#  'repeated-measures': 1,
#  'reprints,': 1,
#  'requirements': 1,
#  'requires': 1,
#  'research': 12,
#  'research,': 2,
#  'researchers': 3,
#  'resistance': 2,
#  'resynthesis,': 1,
#  'review': 3,
#  'review.': 2,
#  'reviewed': 1,
#  'reviewed,': 1,
#  'reviewed.': 1,
#  'reviews,': 1,
#  'rnicholson=AT=pooka.otago.ac.nz': 1,
#  'role': 1,
#  'safe': 1,
#  'safety': 1,
#  'sample': 1,
#  'science,': 1,
#  'scientific': 4,
#  'score': 3,
#  'score,': 1,
#  'scoring': 1,
#  'second': 1,
#  'section': 2,
#  'sections': 1,
#  'seen.': 1,
#  'sense': 1,
#  'sentence': 2,
#  'sentences': 2,
#  'sets': 1,
#  'several': 1,
#  'should': 5,
#  'shown': 2,
#  'shrug,': 1,
#  'significance.': 1,
#  'simulated': 2,
#  'sizes': 1,
#  'skill,': 1,
#  'small': 1,
#  'so': 4,
#  'some': 1,
#  'specificity': 2,
#  'specifics': 1,
#  'speed': 1,
#  'spends': 1,
#  'sport': 3,
#  'sports': 3,
#  'sports.': 1,
#  'sportsci.org/jour/9901/fch.html': 1,
#  'sportsci.org/jour/9901/lmb.html': 1,
#  'sportsci.org/jour/9901/med.html': 1,
#  'sportsci.org/jour/9901/mt23.html': 1,
#  'sportsci.org/jour/9901/rbk.html': 1,
#  'sportsci.org/jour/9901/rmn.html': 1,
#  'sportsci.org/jour/9901/was.html': 1,
#  'sportsci.org/jour/9901/wghedit.html': 1,
#  'sportsci.org/jour/9901/wghnews.html': 1,
#  'sportsci.org/jour/9901/wghpaper.html': 1,
#  'sportsci.org/jour/9901/wghreview.html': 1,
#  'sportsci.org/jour/9901/wghstyle.html': 1,
#  'sportsci.org/news/history/atwater/atwater.html': 1,
#  'stages': 1,
#  'standard': 1,
#  'statistical': 1,
#  'statistics,': 1,
#  'status': 1,
#  'steady-state': 1,
#  'stimulating': 1,
#  'strategies': 2,
#  'strength': 4,
#  'strength-training': 1,
#  'stress.': 1,
#  'structures': 1,
#  'studies': 3,
#  'studies.': 1,
#  'study': 1,
#  'study.': 1,
#  'study;': 1,
#  'studying': 1,
#  'style': 2,
#  'style,': 1,
#  'subjects,': 1,
#  'subtle': 1,
#  'successfully': 1,
#  'summary': 4,
#  'supplementation': 4,
#  'supplementation,': 1,
#  'supplements': 3,
#  'suppression,': 1,
#  'surface': 1,
#  'surfaces': 1,
#  'swim,': 1,
#  'swimmers': 3,
#  'swimmers.': 1,
#  'swimming.': 1,
#  'system': 1,
#  'taken': 1,
#  'targeted': 1,
#  'taught': 1,
#  'teaching': 1,
#  'teaching.': 1,
#  'team': 4,
#  'team-sport': 1,
#  'tempered': 1,
#  'templates,': 1,
#  'tests,': 2,
#  'than': 5,
#  'that': 11,
#  'the': 69,
#  'their': 5,
#  'them': 1,
#  'theoretical': 1,
#  'there': 2,
#  'therefore': 1,
#  'these': 4,
#  'they': 2,
#  'think': 1,
#  'this': 6,
#  'those': 2,
#  'through': 4,
#  'thrust': 3,
#  'thrust,': 1,
#  'thrust-generating': 2,
#  'time': 2,
#  'timers,': 1,
#  'to': 28,
#  'tools,': 1,
#  'top': 1,
#  'trainers': 1,
#  'training': 6,
#  'training.': 2,
#  'training;': 1,
#  'trajectories': 1,
#  'trial': 1,
#  'trial,': 1,
#  'true': 1,
#  'two': 2,
#  'two.': 1,
#  'typical': 1,
#  'uncertain,': 1,
#  'under': 1,
#  'unsteady': 2,
#  'untrained': 1,
#  'unusual.': 1,
#  'use.': 1,
#  'used': 2,
#  'user': 1,
#  'using': 1,
#  'valine)': 1,
#  'value': 1,
#  'variables': 2,
#  'variation': 1,
#  'vault': 2,
#  'video': 1,
#  'view': 1,
#  'vs': 1,
#  'waves.': 1,
#  'way': 1,
#  'ways': 1,
#  'weightlifting,': 1,
#  'weights': 2,
#  'were': 1,
#  'what': 1,
#  'when': 1,
#  'who': 1,
#  'why': 1,
#  'will.hopkins=AT=otago.ac.nz': 5,
#  'winning': 1,
#  'with': 15,
#  'wmasands=AT=concentric.net': 1,
#  'words': 2,
#  'words)': 11,
#  'words.': 2,
#  'work': 3,
#  'worthwhile': 1,
#  'write': 2,
#  'writing': 3,
#  'yet': 1,
#  'yet,': 1,
#  'you': 3,
#  'your': 1}

# %%
stats = {}
previous_word = None
for current_word in words:
  if previous_word in stats:
    
    if current_word in stats[previous_word]:
      stats[previous_word][current_word] +=1
    else:
      stats[previous_word][current_word] =1
  else:
    # the first time we see previous_word
    stats[previous_word] = {current_word: 1}

  previous_word = current_word


stats
# Out:
# {'%0': {'Journal': 13},
#  '%9': {'Editorial': 1, 'News': 5, 'Perspective': 6, 'Review': 1},
#  '%A': {'Burke,': 2,
#   'Daley,': 1,
#   'DeMont,': 1,
#   'Hatfield,': 1,
#   'Hawley,': 1,
#   'Hopkins,': 5,
#   'Katch,': 1,
#   'Kreider,': 1,
#   'McNeil,': 1,
#   'Nicholson,': 1,
#   'Sands,': 1},
#  '%B': {'Sportscience': 13},
#  '%D': {'1999': 13},
#  '%J': {'Sportsci': 13},
#  '%K': {'Internet,': 1,
#   'anabolic,': 1,
#   'analysis,': 2,
#   'biomechanics,': 1,
#   'calorimetry,': 1,
#   'competitions,': 1,
#   'competitive': 1,
#   'data': 1,
#   'dead': 1,
#   'gym': 1,
#   'journal,': 1,
#   'nutrition,': 1},
#  '%N': {'1': 13},
#  '%O': {'Biology': 1,
#   'Department': 11,
#   'Exercise': 1,
#   'International': 1,
#   'School': 1},
#  '%P': {'sportsci.org/jour/9901/fch.html': 1,
#   'sportsci.org/jour/9901/lmb.html': 1,
#   'sportsci.org/jour/9901/med.html': 1,
#   'sportsci.org/jour/9901/mt23.html': 1,
#   'sportsci.org/jour/9901/rbk.html': 1,
#   'sportsci.org/jour/9901/rmn.html': 1,
#   'sportsci.org/jour/9901/was.html': 1,
#   'sportsci.org/jour/9901/wghedit.html': 1,
#   'sportsci.org/jour/9901/wghnews.html': 1,
#   'sportsci.org/jour/9901/wghpaper.html': 1,
#   'sportsci.org/jour/9901/wghreview.html': 1,
#   'sportsci.org/jour/9901/wghstyle.html': 1,
#   'sportsci.org/news/history/atwater/atwater.html': 1},
#  '%T': {'A': 1,
#   'Effects': 1,
#   'Fluid': 1,
#   'Guidelines': 1,
#   'History': 1,
#   'How': 2,
#   'Judging': 1,
#   'Learn': 1,
#   'Moving': 1,
#   'Researching': 1,
#   'Sportscience': 1,
#   'The': 1},
#  '%V': {'3': 13},
#  '%X': {'A': 1,
#   'BACKGROUND.': 3,
#   'For': 1,
#   'Human': 1,
#   'In': 2,
#   'Sportscience,': 1,
#   'The': 1,
#   'Topics': 1,
#   'Two': 1},
#  '&': {'Education,': 1, 'Movement': 1, 'Sport': 2},
#  '(1101': {'words)': 1},
#  '(1559': {'words)': 1},
#  '(1733': {'words)': 1},
#  '(1805': {'words)': 1},
#  '(1844-1907)': {'%J': 1},
#  '(2618': {'words)': 1},
#  '(4397': {'words)': 1},
#  '(5579': {'words)': 1},
#  '(721': {'words)': 1},
#  '(762': {'words)': 1},
#  '(768': {'words)': 1},
#  '(865': {'words)': 1},
#  '(HMB).': {'LITERATURE.': 1},
#  '(e.g.,': {'arginine,': 1},
#  '(hang': {'clean': 1},
#  '(leucine,': {'isoleucine,': 1},
#  '01003.': {'Email:': 1},
#  '1': {'%P': 13},
#  '10': {'published': 1},
#  '19': {'review': 1},
#  '1999': {'%O': 13},
#  '23': {'%J': 1},
#  '25': {'gymnasts': 1},
#  '2616,': {'Australia': 1, 'Australia.': 1},
#  '2W5.': {'Email:': 1},
#  '3': {'%N': 13},
#  '300': {'words.': 2},
#  '3083,': {'Australia': 1},
#  '31': {'original': 1},
#  '38152.': {'Email:': 1},
#  '52557.': {'Email:': 1},
#  '61': {'research': 1},
#  '84112.': {'Email:': 1},
#  '9001,': {'New': 3},
#  '9001.': {'Email:': 3},
#  '93101.': {'Email:': 1},
#  'A': {'new': 2, 'small': 1},
#  'AIM.': {'To': 1},
#  'ANALYSES.': {'Describe': 1},
#  'All': {'supplements': 1},
#  'American': {'Psychological': 1},
#  'Amherst,': {'Maryland,': 1},
#  'Antigonish,': {'Nova': 1},
#  'Article': {'%9': 13},
#  'Association,': {'Santa': 1},
#  'Association.': {'%K': 1},
#  'Atwater': {'(1844-1907)': 1},
#  'Australia': {'%O': 1, '%X': 1},
#  'Australia.': {'Email:': 1},
#  'Australian': {'Institute': 2},
#  'B2G': {'2W5.': 1},
#  'BACKGROUND.': {'In': 2, 'Protein': 1},
#  'BCAA,': {'branched-chain': 1},
#  'Barbara,': {'California': 1},
#  'Be': {'as': 2},
#  'Belconnen': {'2616,': 2},
#  'Biology': {'&': 1, 'Department,': 1},
#  'Branched-chain': {'amino': 1},
#  'Bundoora': {'3083,': 1},
#  'Burke,': {'L.M.': 2},
#  'CONCLUSIONS.': {'Interpret': 1, 'Of': 1, 'This': 1},
#  'California': {'93101.': 1},
#  'Canada': {'B2G': 1},
#  'City,': {'Utah': 1},
#  'Cross-sectional,': {'case-control,': 1},
#  'DESIGN.': {'Cross-sectional,': 1},
#  'Daley,': {'K.': 1},
#  'DeMont,': {'M.E.': 1},
#  'Department': {'of': 12},
#  'Department,': {'St': 1},
#  'Describe': {'methodological': 1, 'the': 1},
#  'Dietary': {'supplementation': 1},
#  'Dunedin': {'9001,': 3},
#  'Dunedin,': {'New': 3},
#  'Editorial': {'%A': 1},
#  'Education,': {'The': 1, 'University': 5},
#  'Effects': {'of': 1},
#  'Email:': {'drsquat=AT=issaonline.com': 1,
#   'edemont=AT=juliet.stfx.ca': 1,
#   'fkatch=AT=excsci.umass.edu': 1,
#   'kdaley=AT=mum.edu': 1,
#   'kreider.richard=AT=coe.memphis.edu': 1,
#   'lburke=AT=ausport.gov.au': 1,
#   'rnicholson=AT=pooka.otago.ac.nz': 1,
#   'will.hopkins=AT=otago.ac.nz': 5,
#   'wmasands=AT=concentric.net': 1},
#  'Exercise': {'&': 2, 'Science,': 1, 'and': 1},
#  'F.C.': {'%T': 1},
#  'F.I.': {'%T': 1},
#  'FINDINGS.': {'Dietary': 1, 'Write': 1},
#  'FURTHER': {'RESEARCH.': 2},
#  'Fairfield,': {'Iowa,': 1},
#  'Fluid': {'and': 1},
#  'For': {'an': 1, 'example:': 1},
#  'Forum': {'contributors': 1},
#  'Francis': {'Xavier': 1},
#  'Give': {'data': 1},
#  'Guidelines': {'on': 1},
#  'HMB,': {'hydroxymethylbutyrate,': 1},
#  'Hatfield,': {'F.C.': 1},
#  'Hawley,': {'J.A.': 1},
#  'History': {'Makers:': 1},
#  'Hopkins,': {'W.G.': 5},
#  'How': {'to': 2},
#  'However,': {'the': 1},
#  'Human': {'Biology': 1, 'Movement': 1, 'judges': 1},
#  'I': {'also': 1, 'present': 1},
#  'In': {'a': 1, 'one': 1, 'the': 1, 'this': 2},
#  'Include': {'any': 1},
#  'Indicate': {'what': 1},
#  'Ingesting': {'carbohydrate': 1},
#  'Institute': {'of': 2},
#  'International': {'Sports': 1},
#  'Internet,': {'kinesiology,': 1},
#  'Interpret': {'the': 1},
#  'Iowa,': {'USA': 1},
#  'J.A.': {'%A': 1},
#  'J.R.': {'%T': 1},
#  'Journal': {'Article': 13},
#  'Judging': {'gymnastics': 1},
#  'K.': {'%T': 1},
#  'Katch,': {'F.I.': 1},
#  'Kreider,': {'R.B.': 1},
#  'L.M.': {'%T': 2},
#  'LITERATURE.': {'List': 1, 'Two': 1},
#  'Laboratory,': {'Department': 1},
#  'Lake': {'City,': 1},
#  'Learn': {'from': 1},
#  'List': {'the': 2},
#  'M.E.': {'%T': 1},
#  'MEASURES.': {'List': 1},
#  'Maharishi': {'University': 1},
#  'Makers:': {'Wilbur': 1},
#  'Management,': {'Fairfield,': 1},
#  'Maryland,': {'USA': 1},
#  'Massachusetts,': {'Amherst,': 1},
#  'McNeil,': {'J.R.': 1},
#  'Measuring': {'enhancements': 1},
#  'Memphis,': {'Memphis,': 1, 'Tennessee': 1},
#  'Most': {'studies': 1},
#  'Movement': {'Science,': 1, 'Sciences': 1},
#  'Moving': {'Together:': 1},
#  "Nature's": {'competitive': 1},
#  'New': {'Zealand': 3, 'Zealand.': 3},
#  'News': {'%A': 5},
#  'Newsletter': {'23': 1},
#  'Nicholson,': {'R.M.': 1},
#  None: {'%0': 1},
#  'Nova': {'Scotia,': 1},
#  'Nutrition': {'Laboratory,': 1},
#  'Nutrition,': {'Australian': 2},
#  'OUTCOMES.': {'State': 1},
#  'Of': {'the': 1},
#  'Olin': {'Atwater': 1},
#  'Olympic': {'weightlifting,': 1},
#  'Otago,': {'Dunedin': 3, 'Dunedin,': 3},
#  'Perspective': {'%A': 6},
#  'Physical': {'Education,': 5},
#  'Physiology': {'and': 4},
#  'Physiology,': {'University': 1},
#  'Protein': {'and': 1},
#  'Psychological': {'Association.': 1},
#  'R.B.': {'%T': 1},
#  'R.M.': {'%T': 1},
#  'RESEARCH.': {'All': 1, 'Indicate': 1},
#  'RMIT': {'University,': 1},
#  'Recent': {'work': 1},
#  'Researching': {'worthwhile': 1},
#  'Review': {'%A': 1},
#  'SUBJECTS.': {'State': 1},
#  'Salt': {'Lake': 1},
#  'Sands,': {'W.A.': 1},
#  'Santa': {'Barbara,': 1},
#  'School': {'of': 5},
#  'Science,': {'RMIT': 1, 'University': 2},
#  'Sciences': {'&': 1, 'Association,': 1},
#  'Sciences,': {'Maharishi': 1},
#  'Scotia,': {'Canada': 1},
#  'Some': {'trainers': 1},
#  'Sport': {'Nutrition': 1, 'Science,': 1, 'Sciences,': 1},
#  'Sport,': {'Belconnen': 2},
#  'Sports': {'Nutrition,': 2, 'Sciences': 1},
#  'Sportsci': {'%B': 13},
#  'Sportscience': {'%V': 13, 'Forum': 1, 'sets': 1},
#  'Sportscience,': {'a': 1},
#  'St': {'Francis': 1},
#  'State': {'the': 1, 'them': 1},
#  'Summary': {'should': 1},
#  'Summary,': {'get': 1},
#  'Supplementation': {'with': 1},
#  'TECHNICALITIES.': {'Describe': 1},
#  'Technology': {'and': 1},
#  'Tennessee': {'38152.': 1},
#  'The': {'University': 1,
#   'dominant': 1,
#   'effects': 1,
#   'guidelines': 1,
#   'lack': 1,
#   'machine': 1,
#   'objective': 1,
#   'power': 1,
#   'second': 1,
#   'summary': 2},
#  'There': {'is': 1},
#  'These': {'forces': 1},
#  'They': {'also': 1},
#  'This': {'review': 1, 'section': 1},
#  'To': {'avoid': 1, 'determine': 1},
#  'Together:': {'Newsletter': 1},
#  'Topics': {'in': 1},
#  'Try': {'to': 1},
#  'Two': {'books,': 1, 'examples': 1},
#  'USA': {'01003.': 1, '52557.': 1},
#  'University': {'of': 10},
#  'University,': {'Antigonish,': 1, 'Bundoora': 1},
#  'Until': {'there': 1},
#  'Use': {'plain': 1},
#  'Utah': {'84112.': 1},
#  'Utah,': {'Salt': 1},
#  'W.A.': {'%A': 1},
#  'W.G.': {'%A': 1, '%T': 4},
#  'We': {'combined': 1, 'have': 1},
#  'Web': {'%0': 1},
#  'Whether': {'employing': 1, 'it': 1},
#  'Wilbur': {'Olin': 1},
#  'Write': {'several': 1},
#  'X': {'and': 1, 'on': 1},
#  'Xavier': {'University,': 1},
#  'Y,': {'and': 1, 'the': 1},
#  'Zealand': {'9001.': 3},
#  'Zealand.': {'Email:': 3},
#  'a': {'competition.': 1,
#   'computer': 1,
#   'conclusion': 1,
#   'descriptive': 1,
#   'difference': 1,
#   'full': 1,
#   'human': 1,
#   'literature': 1,
#   'more': 1,
#   'new': 1,
#   'performance': 1,
#   'recent': 1,
#   'repeated-measures': 1,
#   'research': 1,
#   'sentence': 2,
#   'team': 1,
#   'trial': 1},
#  'abbreviations': {'through': 1},
#  'abbreviations.': {'CONCLUSIONS.': 1},
#  'about': {'half': 1},
#  'abstracts,': {'and': 1},
#  'accurately': {'in': 1},
#  'acids': {'(e.g.,': 1, '(leucine,': 1, 'are': 1, 'enhances': 1},
#  'acids,': {'branched-chain': 1, 'creatine,': 1, 'glutamine,': 1},
#  'adaptations': {'in': 1, 'to': 1},
#  'additional': {'benefits': 1},
#  'adequate': {'precision': 1},
#  'adjustable': {'resistance': 1},
#  'advice': {'based': 1, 'should': 1},
#  'affects': {'training': 1},
#  'agreed': {'that': 2},
#  'air-water': {'interface': 1},
#  'algorithm.': {'We': 1},
#  'allows': {'the': 1},
#  'also': {'agreed': 1, 'deal': 1},
#  'amino': {'acids': 4, 'acids,': 3},
#  'amino-acid': {'supplementation': 1},
#  'among': {'the': 1},
#  'an': {'athlete': 1,
#   'effective': 1,
#   'endurance': 1,
#   'important': 1,
#   'objective': 1},
#  'anabolic': {'amino': 1, 'effects': 1, 'hormonal': 1},
#  'anabolic,': {'BCAA,': 1},
#  'analysis': {'%0': 1},
#  'analysis,': {'design,': 2},
#  'and': {'19': 1,
#   'School': 4,
#   'Sport': 1,
#   'Y,': 1,
#   'a': 1,
#   'abbreviations': 1,
#   'amino': 1,
#   'amino-acid': 1,
#   'analysis': 1,
#   'bibliographic': 1,
#   'carbohydrate': 2,
#   'citation': 1,
#   'dead': 1,
#   'downloadable': 1,
#   'effects': 1,
#   'energy': 1,
#   'experience.': 1,
#   'explain': 1,
#   'fat-free': 1,
#   'glutamine': 1,
#   'hydroxymethylbutyrate': 1,
#   'immune': 1,
#   'increase': 1,
#   'interpret': 1,
#   'no': 1,
#   'phenylalanine)': 1,
#   'potential': 1,
#   'power': 1,
#   'recommendations': 1,
#   'safe': 1,
#   'so': 2,
#   'speed': 1,
#   'standard': 1,
#   'statistics,': 1,
#   'teaching': 1,
#   'the': 1,
#   'to': 1,
#   'valine)': 1,
#   'with': 1},
#  'and/or': {'glucocorticoids,': 1},
#  'animal': {'locomotion': 1},
#  'animals': {'can': 1, 'that': 1},
#  'any': {'major': 1, 'point': 1, 'relevant': 1},
#  'appears': {'to': 2},
#  'appropriate': {'demographics.': 1},
#  'aquatic': {'animal': 1, 'animals': 1},
#  'are': {'among': 1,
#   'available': 1,
#   'better': 1,
#   'effective': 1,
#   'generally': 1,
#   'hard': 1,
#   'important.': 1,
#   'uncertain,': 1},
#  'arginine,': {'histidine,': 1},
#  'argument': {'on': 1},
#  'arise': {'from': 1},
#  'article': {'I': 1, 'templates,': 1},
#  'articles': {'or': 1},
#  'articles,': {'10': 1, 'comprehensible': 1, 'one': 1},
#  'as': {'economical': 2, 'possible,': 2, 'supplements': 1, 'yet,': 1},
#  'at': {'a': 1, 'any': 1, 'present.': 1, 'the': 1},
#  'athlete': {'at': 1},
#  "athlete's": {'typical': 1},
#  'athlete.': {'Some': 1},
#  'athletes': {'involved': 1, 'or': 1, 'should': 1},
#  'athletes,': {'exercise': 1},
#  'athletes.': {'CONCLUSIONS.': 1, 'However,': 1, 'Ingesting': 1, 'This': 1},
#  'athletic': {'caliber,': 1, 'performance': 2, 'performance.': 2},
#  'available': {'to': 1},
#  'avoid': {'confusion': 1},
#  'balance': {'does': 1},
#  'based': {'on': 1},
#  'be': {'an': 1,
#   'done.': 1,
#   'due': 1,
#   'involved': 1,
#   'reevaluated.': 1,
#   'seen.': 1,
#   'taught': 1,
#   'tempered': 1},
#  'because': {'changes': 1},
#  'benefit': {'research': 1},
#  'benefits': {'for': 1},
#  'better': {'research': 1},
#  'between': {'X': 1,
#   'athletes': 1,
#   'competitors': 1,
#   'performances': 1,
#   'studies.': 1},
#  'between-event': {'variation': 1},
#  'beyond': {'that': 1},
#  'bibliographic': {'files.': 1},
#  'bigger': {'sample': 1},
#  'biomechanics': {'%J': 1},
#  'biomechanics,': {'drag,': 1},
#  'biomechanists': {'studying': 1},
#  'book': {'chapters.': 1},
#  'books,': {'61': 1},
#  'branched-chain': {'amino': 2},
#  'but': {'do': 2, 'the': 1, 'their': 1, 'there': 1},
#  'by': {'athletes.': 1,
#   'common': 1,
#   'comparative': 1,
#   'competitive': 1,
#   'optimizing': 1,
#   'stimulating': 1,
#   'the': 1,
#   'using': 1},
#  'caliber,': {'and': 1},
#  'calorimetry,': {'exercise': 1},
#  'can': {'benefit': 1},
#  'carbohydrate': {'feeding': 1, 'intake': 1, 'with': 1},
#  'case-control,': {'randomized': 1},
#  'catabolism': {'and': 1},
#  'catabolism,': {'promote': 1},
#  'central': {'fatigue': 1},
#  'certain': {'amino': 1},
#  'chance': {'of': 1},
#  'change': {'resistance': 1},
#  'changes': {'in': 1},
#  'chapters.': {'FINDINGS.': 1},
#  'citation': {'of': 1},
#  'clean': {'(hang': 1, 'and': 1, 'vs': 1},
#  'clean,': {'Olympic': 1},
#  'cleans': {'and': 1},
#  'clear.': {'There': 1},
#  'clinical': {'studies': 1},
#  'combined': {'the': 1},
#  'common': {'grammatical': 1, 'nutritional': 1, 'sense': 1},
#  'comparative': {'biomechanists': 1},
#  'competition.': {'%K': 1},
#  'competitions,': {'elite': 1},
#  'competitive': {'performance,': 1, 'swimmers': 3},
#  'competitors': {'in': 1},
#  'components': {'of': 1},
#  'comprehensible': {'data': 1},
#  'compromise': {'grammar.': 2},
#  'compulsory': {'vault': 1},
#  'computer': {'algorithm.': 1},
#  'conclusion': {'of': 1},
#  'conditions': {'between': 1},
#  'conferences,': {'lecture': 1},
#  'confusion': {'over': 1},
#  'considerably': {'from': 1},
#  'consist': {'of': 2},
#  'consistency': {'in': 1},
#  'consistent': {'with': 1},
#  'content': {'through': 1},
#  'continue': {'to': 1},
#  'contributes': {'to': 1},
#  'contributors': {'agreed': 1},
#  'controlled': {'trial,': 1},
#  'creates': {'unsteady': 1},
#  'creatine': {'appears': 1, 'supplementation': 1},
#  'creatine,': {'and': 1, 'ergogenic,': 1},
#  'data': {'and': 2, 'are': 1, 'presentation,': 1},
#  'data,': {'common': 1},
#  'dead': {'lift)': 1, 'lift,': 1},
#  'deal': {'with': 1},
#  'decide': {'how': 1},
#  'demographics.': {'MEASURES.': 1},
#  'demonstrate': {'how': 1},
#  'dependent': {'variables': 1},
#  'depth': {'during': 1, 'that': 1},
#  'descriptive': {'study;': 1},
#  'design': {'and': 1},
#  'design,': {'publishing,': 2, 'sports': 1},
#  'determine': {'the': 1},
#  'determining': {'the': 1},
#  'develop': {'power.': 1},
#  'deviations': {'of': 1},
#  'devised': {'an': 1},
#  'devoted': {'to': 1},
#  'differ': {'considerably': 1},
#  'difference': {'to': 1},
#  'differences': {'between': 1, 'in': 2},
#  'differentiation': {'between': 1},
#  'difficulty': {'in': 1},
#  'digitizing,': {'infrared': 1},
#  'discussion': {'on': 1},
#  'do': {'not': 2},
#  'document.': {'I': 1},
#  'documents': {'you': 2},
#  'does': {'not': 1},
#  'dominant': {'view': 1},
#  'done.': {'The': 1},
#  'double-blind': {'controlled': 1},
#  'downloadable': {'article': 1},
#  'drag,': {'fluid': 1},
#  'drag.': {'These': 1},
#  'drinks,': {'supplementation,': 1},
#  'drsquat=AT=issaonline.com': {'%X': 1},
#  'due': {'regard': 1, 'to': 1},
#  'during': {'team': 1, 'the': 1, 'training': 1},
#  'dynamically': {'adjustable': 1},
#  'dynamics,': {'but': 1, 'force,': 1},
#  'each': {'lift': 1, 'targeted': 1},
#  'ease': {'of': 1},
#  'economical': {'with': 2},
#  'edemont=AT=juliet.stfx.ca': {'%X': 1},
#  'education': {'%0': 1},
#  'effect': {'of': 2},
#  'effective': {'and': 1, 'than': 1, 'ways': 1},
#  'effects': {'by': 1, 'of': 2, 'on': 2},
#  'effects.': {'CONCLUSIONS.': 1, 'Use': 1},
#  'elements': {'of': 1},
#  'elite': {'athletes,': 1},
#  'emergency': {'encyclopedia,': 1},
#  'employing': {'these': 1},
#  'encyclopedia,': {'health-fitness...': 1},
#  'endurance': {'athletes.': 1, 'event,': 1},
#  'energy': {'requirements': 1},
#  'enhance': {'adaptations': 1, 'performance': 1},
#  'enhancement': {'makes': 1},
#  'enhancement.': {'%K': 1},
#  'enhancements': {'%J': 1, 'of': 1},
#  'enhances': {'athletic': 1, 'performance': 1},
#  'environment.': {'Whether': 1},
#  'environmental': {'conditions': 1},
#  'equipment,': {'strength': 1},
#  'equivocal': {'at': 1},
#  'ergogenic': {'potential': 1, 'value': 1},
#  'ergogenic,': {'glutamine,': 1},
#  'errors,': {'and': 1},
#  'errors.': {'The': 1},
#  'estimates': {'of': 1},
#  'evaluates': {'the': 1},
#  'evaluation': {'for': 1},
#  'event,': {'so': 1},
#  'evidence': {'from': 1, 'that': 1},
#  'example': {'contributes': 1},
#  'example,': {'work': 1},
#  'example:': {'31': 1},
#  'examples': {'demonstrate': 1},
#  'exercise': {'and': 1,
#   'may': 1,
#   'movement.': 1,
#   'nutrition,': 1,
#   'tests,': 1},
#  'exercise-': {'induced': 1},
#  'experience': {'of': 1},
#  'experience.': {'%K': 1},
#  'explain': {'the': 1, 'why': 1},
#  'explaining': {'any': 1, 'the': 1},
#  'fat-free': {'mass': 1},
#  'fatigue': {'and': 1},
#  'features:': {'new': 1},
#  'feeding': {'on': 1},
#  'field,': {'a': 1},
#  'files.': {'%K': 1},
#  'findings': {'of': 1},
#  'findings,': {'researchers': 1},
#  'first': {'example,': 1, 'section': 1},
#  'five': {'reviews,': 1},
#  'fkatch=AT=excsci.umass.edu': {'%K': 1},
#  'flow': {'of': 1},
#  'fluid': {'and': 1, 'dynamics,': 2, 'motion.': 1},
#  'following': {'exercise': 1},
#  'for': {'a': 2,
#   'articles,': 1,
#   'athletes': 1,
#   'athletes.': 1,
#   'competitive': 1,
#   'form': 1,
#   'publishing': 1,
#   'safety': 1,
#   'scientific': 1,
#   'strength': 1,
#   'the': 3},
#  'force,': {'lift,': 1},
#  'forces': {'arise': 1},
#  'form': {'errors.': 1},
#  'formal': {'research': 1},
#  'four': {'popular': 1},
#  'frame.': {'SUBJECTS.': 1},
#  'free': {'weights': 1},
#  'freestyle': {'swimming.': 1},
#  'from': {"Nature's": 1,
#   'clinical': 1,
#   'steady-state': 1,
#   'the': 1,
#   'those': 1},
#  'full': {'range': 1},
#  'gains': {'in': 1},
#  'game': {'may': 1, 'performance.': 1},
#  'games': {'are': 1, 'to': 1},
#  'games,': {'or': 1},
#  'games:': {'research': 1},
#  'generalizing': {'to': 1},
#  'generally': {'consistent': 1},
#  'generates': {'more': 1},
#  'generating': {'thrust,': 1},
#  'generation': {'in': 1},
#  'get': {'the': 1},
#  'give': {'nutritional': 1},
#  'glide': {'phase': 1},
#  'glucocorticoids,': {'but': 1},
#  'glutamine': {'may': 1},
#  'glutamine,': {'HMB,': 1, 'creatine,': 1},
#  'glycogen': {'resynthesis,': 1},
#  'grammar,': {'punctuation,': 1},
#  'grammar.': {'%K': 2},
#  'grammatical': {'errors,': 1},
#  'greatest': {'ergogenic': 1},
#  'grounds': {'of': 1},
#  'growth': {'hormone,': 1},
#  'guidelines': {'are': 1},
#  'gym': {'equipment,': 1},
#  'gymnastics': {'with': 1},
#  'gymnastics.': {'We': 1},
#  'gymnasts': {'at': 1},
#  'half': {'the': 1},
#  'hang': {'clean,': 1},
#  'hard': {'to': 1},
#  'has': {'shown': 2, 'the': 1},
#  'have': {'anabolic': 1, 'devised': 1, 'difficulty': 1, 'the': 1, 'used': 1},
#  'health-fitness...': {'%K': 1},
#  'here': {'need': 1, 'to': 1},
#  'high-intensity': {'exercise': 1},
#  'histidine,': {'lysine,': 1},
#  'hormonal': {'environment.': 1},
#  'hormone,': {'insulin,': 1},
#  'how': {'it': 1, 'research': 1},
#  'human': {"judge's": 1, 'swimmers.': 1},
#  'hydration': {'status': 1},
#  'hydroxymethylbutyrate': {'(HMB).': 1, 'appears': 1},
#  'hydroxymethylbutyrate,': {'training': 1},
#  'ideas': {'in': 1},
#  'if': {'they': 2},
#  'immune': {'suppression,': 1},
#  'important': {'role': 1},
#  'important.': {'AIM.': 1, 'OUTCOMES.': 1},
#  'improve': {'strength': 1},
#  'in': {'a': 2,
#   'athletes.': 1,
#   'determining': 1,
#   'each': 1,
#   'environmental': 1,
#   'exercise-': 1,
#   'freestyle': 1,
#   'generalizing': 1,
#   'generating': 1,
#   'gymnastics.': 1,
#   'intense': 1,
#   'performance': 1,
#   'performance.': 1,
#   'strength': 1,
#   'team': 1,
#   'the': 6,
#   'these': 1,
#   'this': 3,
#   'trajectories': 1,
#   'untrained': 1},
#  'include': {'a': 1},
#  'included': {'in': 1},
#  'increase': {'gains': 1},
#  'increased': {'the': 1},
#  'indicate': {'that': 1},
#  'individuals': {'initiating': 1},
#  'induced': {'central': 1},
#  'infrared': {'timers,': 1},
#  'initiating': {'training;': 1},
#  'innovative': {'features:': 1},
#  'insights': {'in': 1},
#  'instantly': {'change': 1},
#  'insulin,': {'and/or': 1},
#  'intake': {'during': 1},
#  'intense': {'training.': 1},
#  'interest': {'with': 1},
#  'interface': {'has': 1},
#  'intermittent': {'high-intensity': 1},
#  'interpret': {'magnitudes': 1},
#  'interpretation': {'of': 1},
#  'intervention,': {'or': 1},
#  'investigations,': {'one': 1},
#  'involved': {'in': 3},
#  'is': {'about': 1,
#   'equivocal': 1,
#   'important.': 1,
#   'little': 1,
#   'more': 1,
#   'not': 1,
#   'some': 1,
#   'that': 1,
#   'the': 1},
#  'isoleucine,': {'and': 1},
#  'it': {'affects': 1, 'is': 2},
#  'journal,': {'offers': 1, 'peer-review,': 1},
#  "judge's": {'score': 1},
#  'judge,': {'score,': 1},
#  'judges': {'often': 1},
#  'kdaley=AT=mum.edu': {'%X': 1},
#  'kinesiology,': {'news,': 1},
#  'kreider.richard=AT=coe.memphis.edu': {'%X': 1},
#  'lab': {'tests,': 1},
#  'lack': {'of': 2},
#  'language': {'and': 1},
#  'lburke=AT=ausport.gov.au': {'%X': 1},
#  'lecture': {'notes,': 1},
#  'less': {'than': 2},
#  'lesson': {'plans,': 1},
#  'lift': {'generates': 1, 'need': 1},
#  'lift)': {'on': 1},
#  'lift,': {'hang': 1, 'swim,': 1},
#  'likely': {'ranges': 1},
#  'limitations': {'in': 1},
#  'limited': {'data': 1},
#  'list': {'the': 1},
#  'literature': {'review': 1},
#  'little': {'evidence': 1},
#  'locomotion': {'has': 1},
#  'lysine,': {'methionine,': 1},
#  'machine': {'allows': 1, 'has': 1, 'with': 1},
#  'machines': {'or': 1},
#  'magnitude': {'with': 1},
#  'magnitudes': {'of': 1},
#  'main': {'findings': 1, 'variables': 1},
#  'maintain': {'nitrogen': 1},
#  'major': {'limitations': 1},
#  'makes': {'a': 1},
#  'manuscript.': {'FINDINGS.': 1},
#  'many': {'innovative': 1},
#  'mass': {'in': 1},
#  'maximum': {'stress.': 1},
#  'may': {'be': 3, 'differ': 1, 'reduce': 1},
#  'means': {'and': 1},
#  'measure': {'accurately': 1, 'the': 1},
#  'measurement': {'of': 1},
#  'mechanisms': {'probably': 1, 'used': 1},
#  'medical': {'emergency': 1},
#  'metabolism': {'%0': 1},
#  'methionine,': {'ornithine,': 1},
#  'methodological': {'problems': 1},
#  'minimizes': {'surface': 1},
#  'monograph,': {'five': 1},
#  'more': {'anabolic': 1, 'effective': 1, 'evaluation': 1, 'thrust': 1},
#  'most': {'common': 1},
#  'motion.': {'Recent': 1},
#  'motion;': {'and': 1},
#  'move': {'through': 1},
#  'movement': {'of': 1},
#  'movement.': {'The': 1},
#  'much': {'bigger': 1},
#  'muscle': {'spends': 1},
#  'must': {'consist': 2},
#  'nature': {'of': 1},
#  'necessary': {'to': 1},
#  'need': {'for': 1, 'more': 1, 'only': 1, 'to': 1},
#  'needs': {'to': 1},
#  'new': {'quarterly': 1,
#   'strength-training': 1,
#   'structures': 1,
#   'weights': 1},
#  'news,': {'physical': 1},
#  'newsletter:': {'Technology': 1},
#  'nitrogen': {'balance': 1},
#  'no': {'abbreviations.': 1},
#  'normally': {'use.': 1},
#  'not': {'compromise': 2, 'provide': 1, 'yet': 1},
#  'notes,': {'lesson': 1},
#  'now': {'needs': 1},
#  'number': {'of': 2},
#  'nutrients': {'reviewed,': 1},
#  'nutrition,': {'metabolism': 1, 'research': 1},
#  'nutritional': {'advice': 1,
#   'intervention,': 1,
#   'strategies': 1,
#   'supplements': 1},
#  'objective': {'score': 2, 'scoring': 1},
#  'of': {'25': 1,
#   'Exercise': 3,
#   'Human': 2,
#   'Management,': 1,
#   'Massachusetts,': 1,
#   'Memphis,': 1,
#   'Otago,': 6,
#   'Physical': 5,
#   'Physiology': 4,
#   'Physiology,': 1,
#   'Sport,': 2,
#   'Sports': 2,
#   'Utah,': 1,
#   'X': 1,
#   'an': 1,
#   'consistency': 1,
#   'data,': 1,
#   'effects.': 1,
#   'growth': 1,
#   'hydration': 1,
#   'ideas': 1,
#   'intermittent': 1,
#   'less': 2,
#   'motion;': 1,
#   'nutritional': 1,
#   'performance': 1,
#   'performance,': 1,
#   'practical': 1,
#   'precision': 1,
#   'protein': 2,
#   'protein,': 1,
#   'publications.': 1,
#   'punctuation': 1,
#   'researchers': 1,
#   'scientific': 1,
#   'sport': 1,
#   'subjects,': 1,
#   'teaching.': 1,
#   'the': 8,
#   'their': 3,
#   'these': 2,
#   'this': 1,
#   'thrust': 1,
#   'winning': 1},
#  'offers': {'many': 1},
#  'often': {'have': 1},
#  'on': {'Y,': 1,
#   'aquatic': 2,
#   'athletic': 3,
#   'human': 1,
#   'performance': 1,
#   'research': 1,
#   'simulated': 1,
#   'style': 1,
#   'the': 3},
#  'on.': {'DESIGN.': 1, 'Include': 1},
#  'one': {'manuscript.': 1, 'monograph,': 1, 'or': 1},
#  'ongoing': {'argument': 1},
#  'only': {'a': 1, 'if': 2},
#  'optimal': {'depth': 1},
#  'optimizing': {'the': 1},
#  'or': {'book': 1,
#   'differences': 1,
#   'ease': 1,
#   'following': 1,
#   'free': 1,
#   'insights': 1,
#   'promote': 1,
#   'real': 1,
#   'sports': 1,
#   'the': 1,
#   'two': 2,
#   'two.': 1},
#  'original': {'investigations,': 1},
#  'ornithine,': {'and': 1},
#  'other': {'components': 1, 'machines': 1},
#  'outcomes': {'of': 1, 'qualitatively,': 1},
#  'outline': {'the': 1},
#  'over': {'interpretation': 1},
#  'pace': {'for': 1},
#  'paper': {'%J': 1},
#  'papers,': {'and': 1},
#  'peer-review,': {'sport': 1},
#  'performance': {'%J': 1,
#   'are': 1,
#   'enhancement': 1,
#   'enhancement.': 1,
#   'enhancements': 1,
#   'in': 1,
#   'is': 1,
#   'of': 2},
#  'performance,': {'differences': 1, 'judge,': 1},
#  'performance.': {'%K': 1, 'Branched-chain': 1, 'Measuring': 1, 'The': 1},
#  'performances': {'in': 1},
#  'phase': {'is': 1},
#  'phenylalanine)': {'have': 1},
#  'physical': {'education': 1},
#  'plain': {'language': 1},
#  'plans,': {'medical': 1},
#  'play': {'an': 1},
#  'point': {'in': 1},
#  'popular': {'articles,': 1, 'content': 1},
#  'populations.': {'The': 1},
#  'possible,': {'but': 2},
#  'potential': {'effects': 1, 'for': 1, 'to': 1},
#  'power': {'clean': 2, 'cleans': 1, 'pull': 2, 'pulls': 1, 'shrug,': 1},
#  'power.': {'They': 1},
#  'practical': {'significance.': 1},
#  'precision': {'in': 1, 'of': 1, 'requires': 1},
#  'preferred': {'the': 1},
#  'present': {'the': 1},
#  'present.': {'Most': 1},
#  'presentation': {'of': 1},
#  'presentation,': {'grammar,': 1},
#  'prior': {'to': 1},
#  'probably': {'play': 1},
#  'problems': {'or': 1},
#  'procedures': {'in': 1},
#  'progressively,': {'through': 1},
#  'promote': {'a': 1, 'glycogen': 1},
#  'promoted': {'by': 1},
#  'protein': {'and': 1, 'beyond': 1, 'prior': 1},
#  'protein,': {'purported': 1},
#  'provide': {'additional': 1},
#  'publications.': {'The': 1},
#  'publish': {'and': 1},
#  'published': {'abstracts,': 1},
#  'publishing': {'sport': 1},
#  'publishing,': {'research': 1, 'research,': 2},
#  'pull': {'for': 1, 'or': 1},
#  'pulls': {'are': 1},
#  'punctuation': {'and': 1},
#  'punctuation,': {'publishing,': 1},
#  'purported': {'anabolic': 1},
#  'qualitatively,': {'explaining': 1},
#  'quantitatively,': {'with': 1},
#  'quarterly': {'journal,': 1},
#  'randomized': {'double-blind': 1},
#  'range': {'of': 1},
#  'ranges': {'for': 1},
#  'ranging': {'from': 1},
#  'rationale': {'and': 1},
#  "reader's": {'interest': 1},
#  'real': {'games': 1, 'populations.': 1},
#  'recent': {'discussion': 1},
#  'recommendations': {'%J': 1},
#  'reduce': {'catabolism': 1, 'catabolism,': 1},
#  'reevaluated.': {'%K': 1},
#  'regard': {'to': 1},
#  'relationship': {'between': 1},
#  'release': {'of': 1},
#  'relevant': {'time': 1},
#  'remains': {'to': 1},
#  'repeated-measures': {'study.': 1},
#  'reprints,': {'and': 1},
#  'requirements': {'in': 1},
#  'requires': {'much': 1},
#  'research': {'%0': 1,
#   '%J': 1,
#   'and': 1,
#   'articles,': 1,
#   'design': 1,
#   'design,': 1,
#   'on': 2,
#   'paper': 1,
#   'papers,': 1,
#   'tools,': 1,
#   'with': 1},
#  'research,': {'scientific': 2},
#  'researchers': {'have': 1, 'normally': 1, 'should': 1},
#  'resistance': {'%J': 1, 'at': 1},
#  'resynthesis,': {'or': 1},
#  'review': {'%J': 1, 'articles': 1, 'evaluates': 1},
#  'review.': {'For': 1, 'LITERATURE.': 1},
#  'reviewed': {'here': 1},
#  'reviewed,': {'creatine': 1},
#  'reviewed.': {'Give': 1},
#  'reviews,': {'four': 1},
#  'rnicholson=AT=pooka.otago.ac.nz': {'%X': 1},
#  'role': {'in': 1},
#  'safe': {'way': 1},
#  'safety': {'and': 1},
#  'sample': {'sizes': 1},
#  'science,': {'Web': 1},
#  'scientific': {'style,': 1, 'writing': 3},
#  'score': {'for': 1, 'successfully': 1, 'with': 1},
#  'score,': {'skill,': 1},
#  'scoring': {'system': 1},
#  'second': {'example': 1},
#  'section': {'of': 2},
#  'sections': {'devoted': 1},
#  'seen.': {'%K': 1},
#  'sense': {'and': 1},
#  'sentence': {'or': 2},
#  'sentences': {'explain': 1, 'here': 1},
#  'sets': {'the': 1},
#  'several': {'sentences': 1},
#  'should': {'be': 2, 'continue': 1, 'need': 1, 'therefore': 1},
#  'shown': {'that': 2},
#  'shrug,': {'specificity': 1},
#  'significance.': {'FURTHER': 1},
#  'simulated': {'game': 1, 'games,': 1},
#  'sizes': {'than': 1},
#  'skill,': {'vault': 1},
#  'small': {'number': 1},
#  'so': {'on.': 2, 'the': 2},
#  'some': {'evidence': 1},
#  'specificity': {'%0': 1, 'or': 1},
#  'specifics': {'of': 1},
#  'speed': {'between': 1},
#  'spends': {'under': 1},
#  'sport': {'research': 1, 'science,': 1, 'specificity': 1},
#  'sports': {'%0': 1, 'drinks,': 1, 'in': 1},
#  'sports.': {'A': 1},
#  'sportsci.org/jour/9901/fch.html': {'(762': 1},
#  'sportsci.org/jour/9901/lmb.html': {'(1733': 1},
#  'sportsci.org/jour/9901/med.html': {'(1559': 1},
#  'sportsci.org/jour/9901/mt23.html': {'%D': 1},
#  'sportsci.org/jour/9901/rbk.html': {'(5579': 1},
#  'sportsci.org/jour/9901/rmn.html': {'(768': 1},
#  'sportsci.org/jour/9901/was.html': {'(865': 1},
#  'sportsci.org/jour/9901/wghedit.html': {'(721': 1},
#  'sportsci.org/jour/9901/wghnews.html': {'(1101': 1},
#  'sportsci.org/jour/9901/wghpaper.html': {'(1805': 1},
#  'sportsci.org/jour/9901/wghreview.html': {'(2618': 1},
#  'sportsci.org/jour/9901/wghstyle.html': {'(4397': 1},
#  'sportsci.org/news/history/atwater/atwater.html': {'%D': 1},
#  'stages': {'involved': 1},
#  'standard': {'deviations': 1},
#  'statistical': {'procedures': 1},
#  'statistics,': {'sections': 1},
#  'status': {'and': 1},
#  'steady-state': {'fluid': 1},
#  'stimulating': {'the': 1},
#  'strategies': {'during': 1, 'on': 1},
#  'strength': {'and': 1, 'by': 1, 'training': 2},
#  'strength-training': {'machine': 1},
#  'stress.': {'Whether': 1},
#  'structures': {'for': 1},
#  'studies': {'indicate': 1, 'may': 1, 'that': 1},
#  'studies.': {'Until': 1},
#  'study': {'is': 1},
#  'study.': {'ANALYSES.': 1},
#  'study;': {'list': 1},
#  'studying': {'animals': 1},
#  'style': {'for': 1, 'promoted': 1},
#  'style,': {'ranging': 1},
#  'subjects,': {'their': 1},
#  'subtle': {'differences': 1},
#  'successfully': {'increased': 1},
#  'summary': {'must': 2, 'only': 2},
#  'supplementation': {'may': 1, 'of': 2, 'on': 1},
#  'supplementation,': {'team': 1},
#  'supplements': {'is': 1, 'reviewed': 1, 'taken': 1},
#  'suppression,': {'but': 1},
#  'surface': {'waves.': 1},
#  'surfaces': {'creates': 1},
#  'swim,': {'thrust': 1},
#  'swimmers': {'%J': 1, 'should': 1, 'the': 1},
#  'swimmers.': {'In': 1},
#  'swimming.': {'The': 1},
#  'system': {'for': 1},
#  'taken': {'by': 1},
#  'targeted': {'muscle': 1},
#  'taught': {'progressively,': 1},
#  'teaching': {'conferences,': 1},
#  'teaching.': {'%K': 1},
#  'team': {'game': 1, 'games': 1, 'games:': 1, 'sports': 1},
#  'team-sport': {'athletes': 1},
#  'tempered': {'by': 1},
#  'templates,': {'reprints,': 1},
#  'tests,': {'research': 1, 'simulated': 1},
#  'than': {'300': 2, 'drag.': 1, 'other': 1, 'researchers': 1},
#  'that': {'certain': 1,
#   'creatine': 1,
#   'for': 1,
#   'lift': 1,
#   'minimizes': 1,
#   'move': 1,
#   'necessary': 1,
#   'power': 1,
#   'supplementation': 1,
#   'the': 1,
#   'unsteady': 1},
#  'the': {'American': 1,
#   'Sportscience': 1,
#   'Summary': 1,
#   'Summary,': 1,
#   'advice': 1,
#   'air-water': 1,
#   "athlete's": 1,
#   'athlete.': 1,
#   'chance': 1,
#   'compulsory': 1,
#   'dependent': 1,
#   'depth': 1,
#   'differentiation': 1,
#   'document.': 1,
#   'documents': 2,
#   'effect': 2,
#   'effects': 1,
#   'elements': 1,
#   'exercise': 1,
#   'field,': 1,
#   'first': 1,
#   'flow': 1,
#   'fluid': 1,
#   'glide': 1,
#   'greatest': 1,
#   'grounds': 1,
#   'main': 2,
#   'means': 1,
#   'measurement': 1,
#   'most': 1,
#   'movement': 1,
#   'nature': 1,
#   'need': 1,
#   'number': 1,
#   'nutrients': 1,
#   'nutritional': 1,
#   'objective': 1,
#   'ongoing': 1,
#   'optimal': 1,
#   'other': 1,
#   'outcomes': 2,
#   'pace': 1,
#   'potential': 1,
#   'power': 3,
#   'precision': 1,
#   "reader's": 1,
#   'relationship': 1,
#   'release': 1,
#   'review.': 2,
#   'specifics': 1,
#   'stages': 1,
#   'statistical': 1,
#   'style': 1,
#   'subtle': 1,
#   'theoretical': 1,
#   'thrust-generating': 2,
#   'time': 1,
#   'top': 1,
#   'training': 1,
#   'true': 1,
#   'user': 1},
#  'their': {'appropriate': 1,
#   'athletic': 1,
#   'ergogenic': 1,
#   'estimates': 1,
#   'findings,': 1},
#  'them': {'quantitatively,': 1},
#  'theoretical': {'rationale': 1},
#  'there': {'are': 1, 'is': 1},
#  'therefore': {'publish': 1},
#  'these': {'amino': 1, 'sports.': 1, 'strategies': 1, 'studies': 1},
#  'they': {'are': 1, 'were': 1},
#  'think': {'now': 1},
#  'this': {'article': 1,
#   'first': 1,
#   'magnitude': 1,
#   'newsletter:': 1,
#   'summary': 2},
#  'those': {'of': 1, 'who': 1},
#  'through': {'a': 1, 'formal': 1, 'the': 1, 'to': 1},
#  'thrust': {'%0': 1, 'generation': 1, 'than': 1},
#  'thrust,': {'so': 1},
#  'thrust-generating': {'mechanisms': 1, 'surfaces': 1},
#  'time': {'each': 1, 'frame.': 1},
#  'timers,': {'and': 1},
#  'to': {'be': 3,
#   'decide': 1,
#   'develop': 1,
#   'enhance': 2,
#   'give': 1,
#   'have': 1,
#   'improve': 1,
#   'include': 1,
#   'instantly': 1,
#   'lack': 1,
#   'maintain': 1,
#   'measure': 2,
#   'or': 1,
#   'outline': 1,
#   'popular': 1,
#   'real': 1,
#   'reduce': 1,
#   'the': 4,
#   'training.': 1,
#   'write': 2},
#  'tools,': {'those': 1},
#  'top': {'of': 1},
#  'trainers': {'preferred': 1},
#  'training': {'%0': 1,
#   '%J': 1,
#   'adaptations': 1,
#   'enhances': 1,
#   'experience': 1},
#  'training.': {'FURTHER': 1, 'Supplementation': 1},
#  'training;': {'as': 1},
#  'trajectories': {'and': 1},
#  'trial': {'of': 1},
#  'trial,': {'and': 1},
#  'true': {'effects.': 1},
#  'two': {'explaining': 1, 'sentences': 1},
#  'two.': {'Try': 1},
#  'typical': {'between-event': 1},
#  'uncertain,': {'because': 1},
#  'under': {'maximum': 1},
#  'unsteady': {'fluid': 1, 'mechanisms': 1},
#  'untrained': {'individuals': 1},
#  'unusual.': {'TECHNICALITIES.': 1},
#  'use.': {'To': 1},
#  'used': {'by': 1, 'lab': 1},
#  'user': {'to': 1},
#  'using': {'video': 1},
#  'valine)': {'and': 1},
#  'value': {'as': 1},
#  'variables': {'for': 2},
#  'variation': {'in': 1},
#  'vault': {'%0': 1, 'by': 1},
#  'video': {'digitizing,': 1},
#  'view': {'is': 1},
#  'vs': {'the': 1},
#  'waves.': {'The': 1},
#  'way': {'to': 1},
#  'ways': {'to': 1},
#  'weightlifting,': {'power': 1},
#  'weights': {'machine': 1, 'remains': 1},
#  'were': {'unusual.': 1},
#  'what': {'you': 1},
#  'when': {'it': 1},
#  'who': {'work': 1},
#  'why': {'your': 1},
#  'will.hopkins=AT=otago.ac.nz': {'%O': 1, '%X': 4},
#  'winning': {'when': 1},
#  'with': {'a': 2,
#   'adequate': 1,
#   'biomechanics': 1,
#   'due': 1,
#   'dynamically': 1,
#   'endurance': 1,
#   'hydroxymethylbutyrate': 1,
#   'likely': 1,
#   'presentation': 1,
#   'protein': 1,
#   'team-sport': 1,
#   'the': 1,
#   'words': 2},
#  'wmasands=AT=concentric.net': {'%X': 1},
#  'words': {'as': 2},
#  'words)': {'%D': 11},
#  'words.': {'Be': 2},
#  'work': {'by': 1, 'on': 1, 'with': 1},
#  'worthwhile': {'performance': 1},
#  'write': {'a': 2},
#  'writing': {'%0': 2, '%J': 1},
#  'yet': {'clear.': 1},
#  'yet,': {'limited': 1},
#  'you': {'included': 1, 'reviewed.': 1, 'think': 1},
#  'your': {'study': 1}}

# %%
sentence = "welcome to python course"
print(sentence.split())
# Out:
# ['welcome', 'to', 'python', 'course']

# %%
# compute the conditional probability

P("Programming" | "Python")
P("Course" | "Python")
.
.
.

I will predict the next word after "Python" to be the word with the highest probability

# %%
stats = {}

previous_word = None
for current_word in words:

  if previous_word in stats:
    # I saw previous and current
    if current_word in stats[previous_word]:
      stats[previous_word][current_word] +=1
    # I saw previous_word but not with current_word
    else:
      stats[previous_word][current_word] = 1
  else:
    # first time to see this previous word
    stats[previous_word] = {current_word : 1}


stats
# Out:
# {None: {'%0': 13,
#   '%9': 13,
#   '%A': 16,
#   '%B': 13,
#   '%D': 13,
#   '%J': 13,
#   '%K': 13,
#   '%N': 13,
#   '%O': 15,
#   '%P': 13,
#   '%T': 13,
#   '%V': 13,
#   '%X': 12,
#   '&': 4,
#   '(1101': 1,
#   '(1559': 1,
#   '(1733': 1,
#   '(1805': 1,
#   '(1844-1907)': 1,
#   '(2618': 1,
#   '(4397': 1,
#   '(5579': 1,
#   '(721': 1,
#   '(762': 1,
#   '(768': 1,
#   '(865': 1,
#   '(HMB).': 1,
#   '(e.g.,': 1,
#   '(hang': 1,
#   '(leucine,': 1,
#   '01003.': 1,
#   '1': 13,
#   '10': 1,
#   '19': 1,
#   '1999': 13,
#   '23': 1,
#   '25': 1,
#   '2616,': 2,
#   '2W5.': 1,
#   '3': 13,
#   '300': 2,
#   '3083,': 1,
#   '31': 1,
#   '38152.': 1,
#   '52557.': 1,
#   '61': 1,
#   '84112.': 1,
#   '9001,': 3,
#   '9001.': 3,
#   '93101.': 1,
#   'A': 3,
#   'AIM.': 1,
#   'ANALYSES.': 1,
#   'All': 1,
#   'American': 1,
#   'Amherst,': 1,
#   'Antigonish,': 1,
#   'Article': 13,
#   'Association,': 1,
#   'Association.': 1,
#   'Atwater': 1,
#   'Australia': 2,
#   'Australia.': 1,
#   'Australian': 2,
#   'B2G': 1,
#   'BACKGROUND.': 3,
#   'BCAA,': 1,
#   'Barbara,': 1,
#   'Be': 2,
#   'Belconnen': 2,
#   'Biology': 2,
#   'Branched-chain': 1,
#   'Bundoora': 1,
#   'Burke,': 2,
#   'CONCLUSIONS.': 3,
#   'California': 1,
#   'Canada': 1,
#   'City,': 1,
#   'Cross-sectional,': 1,
#   'DESIGN.': 1,
#   'Daley,': 1,
#   'DeMont,': 1,
#   'Department': 12,
#   'Department,': 1,
#   'Describe': 2,
#   'Dietary': 1,
#   'Dunedin': 3,
#   'Dunedin,': 3,
#   'Editorial': 1,
#   'Education,': 6,
#   'Effects': 1,
#   'Email:': 13,
#   'Exercise': 4,
#   'F.C.': 1,
#   'F.I.': 1,
#   'FINDINGS.': 2,
#   'FURTHER': 2,
#   'Fairfield,': 1,
#   'Fluid': 1,
#   'For': 2,
#   'Forum': 1,
#   'Francis': 1,
#   'Give': 1,
#   'Guidelines': 1,
#   'HMB,': 1,
#   'Hatfield,': 1,
#   'Hawley,': 1,
#   'History': 1,
#   'Hopkins,': 5,
#   'How': 2,
#   'However,': 1,
#   'Human': 3,
#   'I': 2,
#   'In': 5,
#   'Include': 1,
#   'Indicate': 1,
#   'Ingesting': 1,
#   'Institute': 2,
#   'International': 1,
#   'Internet,': 1,
#   'Interpret': 1,
#   'Iowa,': 1,
#   'J.A.': 1,
#   'J.R.': 1,
#   'Journal': 13,
#   'Judging': 1,
#   'K.': 1,
#   'Katch,': 1,
#   'Kreider,': 1,
#   'L.M.': 2,
#   'LITERATURE.': 2,
#   'Laboratory,': 1,
#   'Lake': 1,
#   'Learn': 1,
#   'List': 2,
#   'M.E.': 1,
#   'MEASURES.': 1,
#   'Maharishi': 1,
#   'Makers:': 1,
#   'Management,': 1,
#   'Maryland,': 1,
#   'Massachusetts,': 1,
#   'McNeil,': 1,
#   'Measuring': 1,
#   'Memphis,': 2,
#   'Most': 1,
#   'Movement': 2,
#   'Moving': 1,
#   "Nature's": 1,
#   'New': 6,
#   'News': 5,
#   'Newsletter': 1,
#   'Nicholson,': 1,
#   'Nova': 1,
#   'Nutrition': 1,
#   'Nutrition,': 2,
#   'OUTCOMES.': 1,
#   'Of': 1,
#   'Olin': 1,
#   'Olympic': 1,
#   'Otago,': 6,
#   'Perspective': 6,
#   'Physical': 5,
#   'Physiology': 4,
#   'Physiology,': 1,
#   'Protein': 1,
#   'Psychological': 1,
#   'R.B.': 1,
#   'R.M.': 1,
#   'RESEARCH.': 2,
#   'RMIT': 1,
#   'Recent': 1,
#   'Researching': 1,
#   'Review': 1,
#   'SUBJECTS.': 1,
#   'Salt': 1,
#   'Sands,': 1,
#   'Santa': 1,
#   'School': 5,
#   'Science,': 3,
#   'Sciences': 2,
#   'Sciences,': 1,
#   'Scotia,': 1,
#   'Some': 1,
#   'Sport': 3,
#   'Sport,': 2,
#   'Sports': 3,
#   'Sportsci': 13,
#   'Sportscience': 15,
#   'Sportscience,': 1,
#   'St': 1,
#   'State': 2,
#   'Summary': 1,
#   'Summary,': 1,
#   'Supplementation': 1,
#   'TECHNICALITIES.': 1,
#   'Technology': 1,
#   'Tennessee': 1,
#   'The': 11,
#   'There': 1,
#   'These': 1,
#   'They': 1,
#   'This': 2,
#   'To': 2,
#   'Together:': 1,
#   'Topics': 1,
#   'Try': 1,
#   'Two': 2,
#   'USA': 2,
#   'University': 10,
#   'University,': 2,
#   'Until': 1,
#   'Use': 1,
#   'Utah': 1,
#   'Utah,': 1,
#   'W.A.': 1,
#   'W.G.': 5,
#   'We': 2,
#   'Web': 1,
#   'Whether': 2,
#   'Wilbur': 1,
#   'Write': 1,
#   'X': 2,
#   'Xavier': 1,
#   'Y,': 2,
#   'Zealand': 3,
#   'Zealand.': 3,
#   'a': 18,
#   'abbreviations': 1,
#   'abbreviations.': 1,
#   'about': 1,
#   'abstracts,': 1,
#   'accurately': 1,
#   'acids': 4,
#   'acids,': 3,
#   'adaptations': 2,
#   'additional': 1,
#   'adequate': 1,
#   'adjustable': 1,
#   'advice': 2,
#   'affects': 1,
#   'agreed': 2,
#   'air-water': 1,
#   'algorithm.': 1,
#   'allows': 1,
#   'also': 2,
#   'amino': 7,
#   'amino-acid': 1,
#   'among': 1,
#   'an': 5,
#   'anabolic': 3,
#   'anabolic,': 1,
#   'analysis': 1,
#   'analysis,': 2,
#   'and': 44,
#   'and/or': 1,
#   'animal': 1,
#   'animals': 2,
#   'any': 3,
#   'appears': 2,
#   'appropriate': 1,
#   'aquatic': 2,
#   'are': 8,
#   'arginine,': 1,
#   'argument': 1,
#   'arise': 1,
#   'article': 2,
#   'articles': 1,
#   'articles,': 3,
#   'as': 6,
#   'at': 4,
#   'athlete': 1,
#   "athlete's": 1,
#   'athlete.': 1,
#   'athletes': 3,
#   'athletes,': 1,
#   'athletes.': 4,
#   'athletic': 5,
#   'available': 1,
#   'avoid': 1,
#   'balance': 1,
#   'based': 1,
#   'be': 8,
#   'because': 1,
#   'benefit': 1,
#   'benefits': 1,
#   'better': 1,
#   'between': 5,
#   'between-event': 1,
#   'beyond': 1,
#   'bibliographic': 1,
#   'bigger': 1,
#   'biomechanics': 1,
#   'biomechanics,': 1,
#   'biomechanists': 1,
#   'book': 1,
#   'books,': 1,
#   'branched-chain': 2,
#   'but': 5,
#   'by': 8,
#   'caliber,': 1,
#   'calorimetry,': 1,
#   'can': 1,
#   'carbohydrate': 3,
#   'case-control,': 1,
#   'catabolism': 1,
#   'catabolism,': 1,
#   'central': 1,
#   'certain': 1,
#   'chance': 1,
#   'change': 1,
#   'changes': 1,
#   'chapters.': 1,
#   'citation': 1,
#   'clean': 3,
#   'clean,': 1,
#   'cleans': 1,
#   'clear.': 1,
#   'clinical': 1,
#   'combined': 1,
#   'common': 3,
#   'comparative': 1,
#   'competition.': 1,
#   'competitions,': 1,
#   'competitive': 4,
#   'competitors': 1,
#   'components': 1,
#   'comprehensible': 1,
#   'compromise': 2,
#   'compulsory': 1,
#   'computer': 1,
#   'conclusion': 1,
#   'conditions': 1,
#   'conferences,': 1,
#   'confusion': 1,
#   'considerably': 1,
#   'consist': 2,
#   'consistency': 1,
#   'consistent': 1,
#   'content': 1,
#   'continue': 1,
#   'contributes': 1,
#   'contributors': 1,
#   'controlled': 1,
#   'creates': 1,
#   'creatine': 2,
#   'creatine,': 2,
#   'data': 4,
#   'data,': 1,
#   'dead': 2,
#   'deal': 1,
#   'decide': 1,
#   'demographics.': 1,
#   'demonstrate': 1,
#   'dependent': 1,
#   'depth': 2,
#   'descriptive': 1,
#   'design': 1,
#   'design,': 3,
#   'determine': 1,
#   'determining': 1,
#   'develop': 1,
#   'deviations': 1,
#   'devised': 1,
#   'devoted': 1,
#   'differ': 1,
#   'difference': 1,
#   'differences': 3,
#   'differentiation': 1,
#   'difficulty': 1,
#   'digitizing,': 1,
#   'discussion': 1,
#   'do': 2,
#   'document.': 1,
#   'documents': 2,
#   'does': 1,
#   'dominant': 1,
#   'done.': 1,
#   'double-blind': 1,
#   'downloadable': 1,
#   'drag,': 1,
#   'drag.': 1,
#   'drinks,': 1,
#   'drsquat=AT=issaonline.com': 1,
#   'due': 2,
#   'during': 3,
#   'dynamically': 1,
#   'dynamics,': 2,
#   'each': 2,
#   'ease': 1,
#   'economical': 2,
#   'edemont=AT=juliet.stfx.ca': 1,
#   'education': 1,
#   'effect': 2,
#   'effective': 3,
#   'effects': 5,
#   'effects.': 2,
#   'elements': 1,
#   'elite': 1,
#   'emergency': 1,
#   'employing': 1,
#   'encyclopedia,': 1,
#   'endurance': 2,
#   'energy': 1,
#   'enhance': 2,
#   'enhancement': 1,
#   'enhancement.': 1,
#   'enhancements': 2,
#   'enhances': 2,
#   'environment.': 1,
#   'environmental': 1,
#   'equipment,': 1,
#   'equivocal': 1,
#   'ergogenic': 2,
#   'ergogenic,': 1,
#   'errors,': 1,
#   'errors.': 1,
#   'estimates': 1,
#   'evaluates': 1,
#   'evaluation': 1,
#   'event,': 1,
#   'evidence': 2,
#   'example': 1,
#   'example,': 1,
#   'example:': 1,
#   'examples': 1,
#   'exercise': 5,
#   'exercise-': 1,
#   'experience': 1,
#   'experience.': 1,
#   'explain': 2,
#   'explaining': 2,
#   'fat-free': 1,
#   'fatigue': 1,
#   'features:': 1,
#   'feeding': 1,
#   'field,': 1,
#   'files.': 1,
#   'findings': 1,
#   'findings,': 1,
#   'first': 2,
#   'five': 1,
#   'fkatch=AT=excsci.umass.edu': 1,
#   'flow': 1,
#   'fluid': 4,
#   'following': 1,
#   'for': 14,
#   'force,': 1,
#   'forces': 1,
#   'form': 1,
#   'formal': 1,
#   'four': 1,
#   'frame.': 1,
#   'free': 1,
#   'freestyle': 1,
#   'from': 5,
#   'full': 1,
#   'gains': 1,
#   'game': 2,
#   'games': 2,
#   'games,': 1,
#   'games:': 1,
#   'generalizing': 1,
#   'generally': 1,
#   'generates': 1,
#   'generating': 1,
#   'generation': 1,
#   'get': 1,
#   'give': 1,
#   'glide': 1,
#   'glucocorticoids,': 1,
#   'glutamine': 1,
#   'glutamine,': 2,
#   'glycogen': 1,
#   'grammar,': 1,
#   'grammar.': 2,
#   'grammatical': 1,
#   'greatest': 1,
#   'grounds': 1,
#   'growth': 1,
#   'guidelines': 1,
#   'gym': 1,
#   'gymnastics': 1,
#   'gymnastics.': 1,
#   'gymnasts': 1,
#   'half': 1,
#   'hang': 1,
#   'hard': 1,
#   'has': 3,
#   'have': 5,
#   'health-fitness...': 1,
#   'here': 2,
#   'high-intensity': 1,
#   'histidine,': 1,
#   'hormonal': 1,
#   'hormone,': 1,
#   'how': 2,
#   'human': 2,
#   'hydration': 1,
#   'hydroxymethylbutyrate': 2,
#   'hydroxymethylbutyrate,': 1,
#   'ideas': 1,
#   'if': 2,
#   'immune': 1,
#   'important': 1,
#   'important.': 2,
#   'improve': 1,
#   'in': 28,
#   'include': 1,
#   'included': 1,
#   'increase': 1,
#   'increased': 1,
#   'indicate': 1,
#   'individuals': 1,
#   'induced': 1,
#   'infrared': 1,
#   'initiating': 1,
#   'innovative': 1,
#   'insights': 1,
#   'instantly': 1,
#   'insulin,': 1,
#   'intake': 1,
#   'intense': 1,
#   'interest': 1,
#   'interface': 1,
#   'intermittent': 1,
#   'interpret': 1,
#   'interpretation': 1,
#   'intervention,': 1,
#   'investigations,': 1,
#   'involved': 3,
#   'is': 9,
#   'isoleucine,': 1,
#   'it': 3,
#   'journal,': 2,
#   "judge's": 1,
#   'judge,': 1,
#   'judges': 1,
#   'kdaley=AT=mum.edu': 1,
#   'kinesiology,': 1,
#   'kreider.richard=AT=coe.memphis.edu': 1,
#   'lab': 1,
#   'lack': 2,
#   'language': 1,
#   'lburke=AT=ausport.gov.au': 1,
#   'lecture': 1,
#   'less': 2,
#   'lesson': 1,
#   'lift': 2,
#   'lift)': 1,
#   'lift,': 2,
#   'likely': 1,
#   'limitations': 1,
#   'limited': 1,
#   'list': 1,
#   'literature': 1,
#   'little': 1,
#   'locomotion': 1,
#   'lysine,': 1,
#   'machine': 3,
#   'machines': 1,
#   'magnitude': 1,
#   'magnitudes': 1,
#   'main': 2,
#   'maintain': 1,
#   'major': 1,
#   'makes': 1,
#   'manuscript.': 1,
#   'many': 1,
#   'mass': 1,
#   'maximum': 1,
#   'may': 5,
#   'means': 1,
#   'measure': 2,
#   'measurement': 1,
#   'mechanisms': 2,
#   'medical': 1,
#   'metabolism': 1,
#   'methionine,': 1,
#   'methodological': 1,
#   'minimizes': 1,
#   'monograph,': 1,
#   'more': 4,
#   'most': 1,
#   'motion.': 1,
#   'motion;': 1,
#   'move': 1,
#   'movement': 1,
#   'movement.': 1,
#   'much': 1,
#   'muscle': 1,
#   'must': 2,
#   'nature': 1,
#   'necessary': 1,
#   'need': 4,
#   'needs': 1,
#   'new': 4,
#   'news,': 1,
#   'newsletter:': 1,
#   'nitrogen': 1,
#   'no': 1,
#   'normally': 1,
#   'not': 4,
#   'notes,': 1,
#   'now': 1,
#   'number': 2,
#   'nutrients': 1,
#   'nutrition,': 2,
#   'nutritional': 4,
#   'objective': 3,
#   'of': 73,
#   'offers': 1,
#   'often': 1,
#   'on': 14,
#   'on.': 2,
#   'one': 3,
#   'ongoing': 1,
#   'only': 3,
#   'optimal': 1,
#   'optimizing': 1,
#   'or': 13,
#   'original': 1,
#   'ornithine,': 1,
#   'other': 2,
#   'outcomes': 2,
#   'outline': 1,
#   'over': 1,
#   'pace': 1,
#   'paper': 1,
#   'papers,': 1,
#   'peer-review,': 1,
#   'performance': 9,
#   'performance,': 2,
#   'performance.': 4,
#   'performances': 1,
#   'phase': 1,
#   'phenylalanine)': 1,
#   'physical': 1,
#   'plain': 1,
#   'plans,': 1,
#   'play': 1,
#   'point': 1,
#   'popular': 2,
#   'populations.': 1,
#   'possible,': 2,
#   'potential': 3,
#   'power': 7,
#   'power.': 1,
#   'practical': 1,
#   'precision': 3,
#   'preferred': 1,
#   'present': 1,
#   'present.': 1,
#   'presentation': 1,
#   'presentation,': 1,
#   'prior': 1,
#   'probably': 1,
#   'problems': 1,
#   'procedures': 1,
#   'progressively,': 1,
#   'promote': 2,
#   'promoted': 1,
#   'protein': 3,
#   'protein,': 1,
#   'provide': 1,
#   'publications.': 1,
#   'publish': 1,
#   'published': 1,
#   'publishing': 1,
#   'publishing,': 3,
#   'pull': 2,
#   'pulls': 1,
#   'punctuation': 1,
#   'punctuation,': 1,
#   'purported': 1,
#   'qualitatively,': 1,
#   'quantitatively,': 1,
#   'quarterly': 1,
#   'randomized': 1,
#   'range': 1,
#   'ranges': 1,
#   'ranging': 1,
#   'rationale': 1,
#   "reader's": 1,
#   'real': 2,
#   'recent': 1,
#   'recommendations': 1,
#   'reduce': 2,
#   'reevaluated.': 1,
#   'regard': 1,
#   'relationship': 1,
#   'release': 1,
#   'relevant': 1,
#   'remains': 1,
#   'repeated-measures': 1,
#   'reprints,': 1,
#   'requirements': 1,
#   'requires': 1,
#   'research': 12,
#   'research,': 2,
#   'researchers': 3,
#   'resistance': 2,
#   'resynthesis,': 1,
#   'review': 3,
#   'review.': 2,
#   'reviewed': 1,
#   'reviewed,': 1,
#   'reviewed.': 1,
#   'reviews,': 1,
#   'rnicholson=AT=pooka.otago.ac.nz': 1,
#   'role': 1,
#   'safe': 1,
#   'safety': 1,
#   'sample': 1,
#   'science,': 1,
#   'scientific': 4,
#   'score': 3,
#   'score,': 1,
#   'scoring': 1,
#   'second': 1,
#   'section': 2,
#   'sections': 1,
#   'seen.': 1,
#   'sense': 1,
#   'sentence': 2,
#   'sentences': 2,
#   'sets': 1,
#   'several': 1,
#   'should': 5,
#   'shown': 2,
#   'shrug,': 1,
#   'significance.': 1,
#   'simulated': 2,
#   'sizes': 1,
#   'skill,': 1,
#   'small': 1,
#   'so': 4,
#   'some': 1,
#   'specificity': 2,
#   'specifics': 1,
#   'speed': 1,
#   'spends': 1,
#   'sport': 3,
#   'sports': 3,
#   'sports.': 1,
#   'sportsci.org/jour/9901/fch.html': 1,
#   'sportsci.org/jour/9901/lmb.html': 1,
#   'sportsci.org/jour/9901/med.html': 1,
#   'sportsci.org/jour/9901/mt23.html': 1,
#   'sportsci.org/jour/9901/rbk.html': 1,
#   'sportsci.org/jour/9901/rmn.html': 1,
#   'sportsci.org/jour/9901/was.html': 1,
#   'sportsci.org/jour/9901/wghedit.html': 1,
#   'sportsci.org/jour/9901/wghnews.html': 1,
#   'sportsci.org/jour/9901/wghpaper.html': 1,
#   'sportsci.org/jour/9901/wghreview.html': 1,
#   'sportsci.org/jour/9901/wghstyle.html': 1,
#   'sportsci.org/news/history/atwater/atwater.html': 1,
#   'stages': 1,
#   'standard': 1,
#   'statistical': 1,
#   'statistics,': 1,
#   'status': 1,
#   'steady-state': 1,
#   'stimulating': 1,
#   'strategies': 2,
#   'strength': 4,
#   'strength-training': 1,
#   'stress.': 1,
#   'structures': 1,
#   'studies': 3,
#   'studies.': 1,
#   'study': 1,
#   'study.': 1,
#   'study;': 1,
#   'studying': 1,
#   'style': 2,
#   'style,': 1,
#   'subjects,': 1,
#   'subtle': 1,
#   'successfully': 1,
#   'summary': 4,
#   'supplementation': 4,
#   'supplementation,': 1,
#   'supplements': 3,
#   'suppression,': 1,
#   'surface': 1,
#   'surfaces': 1,
#   'swim,': 1,
#   'swimmers': 3,
#   'swimmers.': 1,
#   'swimming.': 1,
#   'system': 1,
#   'taken': 1,
#   'targeted': 1,
#   'taught': 1,
#   'teaching': 1,
#   'teaching.': 1,
#   'team': 4,
#   'team-sport': 1,
#   'tempered': 1,
#   'templates,': 1,
#   'tests,': 2,
#   'than': 5,
#   'that': 11,
#   'the': 69,
#   'their': 5,
#   'them': 1,
#   'theoretical': 1,
#   'there': 2,
#   'therefore': 1,
#   'these': 4,
#   'they': 2,
#   'think': 1,
#   'this': 6,
#   'those': 2,
#   'through': 4,
#   'thrust': 3,
#   'thrust,': 1,
#   'thrust-generating': 2,
#   'time': 2,
#   'timers,': 1,
#   'to': 28,
#   'tools,': 1,
#   'top': 1,
#   'trainers': 1,
#   'training': 6,
#   'training.': 2,
#   'training;': 1,
#   'trajectories': 1,
#   'trial': 1,
#   'trial,': 1,
#   'true': 1,
#   'two': 2,
#   'two.': 1,
#   'typical': 1,
#   'uncertain,': 1,
#   'under': 1,
#   'unsteady': 2,
#   'untrained': 1,
#   'unusual.': 1,
#   'use.': 1,
#   'used': 2,
#   'user': 1,
#   'using': 1,
#   'valine)': 1,
#   'value': 1,
#   'variables': 2,
#   'variation': 1,
#   'vault': 2,
#   'video': 1,
#   'view': 1,
#   'vs': 1,
#   'waves.': 1,
#   'way': 1,
#   'ways': 1,
#   'weightlifting,': 1,
#   'weights': 2,
#   'were': 1,
#   'what': 1,
#   'when': 1,
#   'who': 1,
#   'why': 1,
#   'will.hopkins=AT=otago.ac.nz': 5,
#   'winning': 1,
#   'with': 15,
#   'wmasands=AT=concentric.net': 1,
#   'words': 2,
#   'words)': 11,
#   'words.': 2,
#   'work': 3,
#   'worthwhile': 1,
#   'write': 2,
#   'writing': 3,
#   'yet': 1,
#   'yet,': 1,
#   'you': 3,
#   'your': 1}}

# %%
#{"Python": { "Course": 5,
#             "Programming": 1},               
#"University": {"ANN": 40,
#                "Birzeit": 10}}


words_stats = {}

previous_word = None
# loop through all words from the file
for current_word in words:
  # we must have a previous word to compute the conditional probability
  if previous_word is not None:
    # if the previous word already seen in the file
    if previous_word in words_stats:
      # increase counter for previous_word
      words_stats[previous_word]['count'] += 1

      # if both the previous and current words are seen before
      if current_word in words_stats[previous_word]:
          words_stats[previous_word][current_word] += 1
      # first time to see current_word following such a previous word
      else:
        words_stats[previous_word][current_word] = 1
  
    # this is the first time I see such a previous word
    else:
      words_stats[previous_word] = {current_word: 1, 'count': 1}

    

  previous_word = current_word

# %%
{ "football": {'count': 7, "play": 2, "game": 5},
  "City": {'count': 18, "Nablus": 15, "Ramallah": 3}}

# %%
{ "football": {"play": 2, "game": 5},
  "City": {"Nablus": 15, "Ramallah": 3}}


{"football": 7,
 "City:": 18,
 ,
 ,
 }

# %%
words_stats
# Out:
# {'%0': {'Journal': 13, 'count': 13},
#  '%9': {'Editorial': 1, 'News': 5, 'Perspective': 6, 'Review': 1, 'count': 13},
#  '%A': {'Burke,': 2,
#   'Daley,': 1,
#   'DeMont,': 1,
#   'Hatfield,': 1,
#   'Hawley,': 1,
#   'Hopkins,': 5,
#   'Katch,': 1,
#   'Kreider,': 1,
#   'McNeil,': 1,
#   'Nicholson,': 1,
#   'Sands,': 1,
#   'count': 16},
#  '%B': {'Sportscience': 13, 'count': 13},
#  '%D': {'1999': 13, 'count': 13},
#  '%J': {'Sportsci': 13, 'count': 13},
#  '%K': {'Internet,': 1,
#   'anabolic,': 1,
#   'analysis,': 2,
#   'biomechanics,': 1,
#   'calorimetry,': 1,
#   'competitions,': 1,
#   'competitive': 1,
#   'count': 13,
#   'data': 1,
#   'dead': 1,
#   'gym': 1,
#   'journal,': 1,
#   'nutrition,': 1},
#  '%N': {'1': 13, 'count': 13},
#  '%O': {'Biology': 1,
#   'Department': 11,
#   'Exercise': 1,
#   'International': 1,
#   'School': 1,
#   'count': 15},
#  '%P': {'count': 13,
#   'sportsci.org/jour/9901/fch.html': 1,
#   'sportsci.org/jour/9901/lmb.html': 1,
#   'sportsci.org/jour/9901/med.html': 1,
#   'sportsci.org/jour/9901/mt23.html': 1,
#   'sportsci.org/jour/9901/rbk.html': 1,
#   'sportsci.org/jour/9901/rmn.html': 1,
#   'sportsci.org/jour/9901/was.html': 1,
#   'sportsci.org/jour/9901/wghedit.html': 1,
#   'sportsci.org/jour/9901/wghnews.html': 1,
#   'sportsci.org/jour/9901/wghpaper.html': 1,
#   'sportsci.org/jour/9901/wghreview.html': 1,
#   'sportsci.org/jour/9901/wghstyle.html': 1,
#   'sportsci.org/news/history/atwater/atwater.html': 1},
#  '%T': {'A': 1,
#   'Effects': 1,
#   'Fluid': 1,
#   'Guidelines': 1,
#   'History': 1,
#   'How': 2,
#   'Judging': 1,
#   'Learn': 1,
#   'Moving': 1,
#   'Researching': 1,
#   'Sportscience': 1,
#   'The': 1,
#   'count': 13},
#  '%V': {'3': 13, 'count': 13},
#  '%X': {'A': 1,
#   'BACKGROUND.': 3,
#   'For': 1,
#   'Human': 1,
#   'In': 2,
#   'Sportscience,': 1,
#   'The': 1,
#   'Topics': 1,
#   'Two': 1,
#   'count': 12},
#  '&': {'Education,': 1, 'Movement': 1, 'Sport': 2, 'count': 4},
#  '(1101': {'count': 1, 'words)': 1},
#  '(1559': {'count': 1, 'words)': 1},
#  '(1733': {'count': 1, 'words)': 1},
#  '(1805': {'count': 1, 'words)': 1},
#  '(1844-1907)': {'%J': 1, 'count': 1},
#  '(2618': {'count': 1, 'words)': 1},
#  '(4397': {'count': 1, 'words)': 1},
#  '(5579': {'count': 1, 'words)': 1},
#  '(721': {'count': 1, 'words)': 1},
#  '(762': {'count': 1, 'words)': 1},
#  '(768': {'count': 1, 'words)': 1},
#  '(865': {'count': 1, 'words)': 1},
#  '(HMB).': {'LITERATURE.': 1, 'count': 1},
#  '(e.g.,': {'arginine,': 1, 'count': 1},
#  '(hang': {'clean': 1, 'count': 1},
#  '(leucine,': {'count': 1, 'isoleucine,': 1},
#  '01003.': {'Email:': 1, 'count': 1},
#  '1': {'%P': 13, 'count': 13},
#  '10': {'count': 1, 'published': 1},
#  '19': {'count': 1, 'review': 1},
#  '1999': {'%O': 13, 'count': 13},
#  '23': {'%J': 1, 'count': 1},
#  '25': {'count': 1, 'gymnasts': 1},
#  '2616,': {'Australia': 1, 'Australia.': 1, 'count': 2},
#  '2W5.': {'Email:': 1, 'count': 1},
#  '3': {'%N': 13, 'count': 13},
#  '300': {'count': 2, 'words.': 2},
#  '3083,': {'Australia': 1, 'count': 1},
#  '31': {'count': 1, 'original': 1},
#  '38152.': {'Email:': 1, 'count': 1},
#  '52557.': {'Email:': 1, 'count': 1},
#  '61': {'count': 1, 'research': 1},
#  '84112.': {'Email:': 1, 'count': 1},
#  '9001,': {'New': 3, 'count': 3},
#  '9001.': {'Email:': 3, 'count': 3},
#  '93101.': {'Email:': 1, 'count': 1},
#  'A': {'count': 3, 'new': 2, 'small': 1},
#  'AIM.': {'To': 1, 'count': 1},
#  'ANALYSES.': {'Describe': 1, 'count': 1},
#  'All': {'count': 1, 'supplements': 1},
#  'American': {'Psychological': 1, 'count': 1},
#  'Amherst,': {'Maryland,': 1, 'count': 1},
#  'Antigonish,': {'Nova': 1, 'count': 1},
#  'Article': {'%9': 13, 'count': 13},
#  'Association,': {'Santa': 1, 'count': 1},
#  'Association.': {'%K': 1, 'count': 1},
#  'Atwater': {'(1844-1907)': 1, 'count': 1},
#  'Australia': {'%O': 1, '%X': 1, 'count': 2},
#  'Australia.': {'Email:': 1, 'count': 1},
#  'Australian': {'Institute': 2, 'count': 2},
#  'B2G': {'2W5.': 1, 'count': 1},
#  'BACKGROUND.': {'In': 2, 'Protein': 1, 'count': 3},
#  'BCAA,': {'branched-chain': 1, 'count': 1},
#  'Barbara,': {'California': 1, 'count': 1},
#  'Be': {'as': 2, 'count': 2},
#  'Belconnen': {'2616,': 2, 'count': 2},
#  'Biology': {'&': 1, 'Department,': 1, 'count': 2},
#  'Branched-chain': {'amino': 1, 'count': 1},
#  'Bundoora': {'3083,': 1, 'count': 1},
#  'Burke,': {'L.M.': 2, 'count': 2},
#  'CONCLUSIONS.': {'Interpret': 1, 'Of': 1, 'This': 1, 'count': 3},
#  'California': {'93101.': 1, 'count': 1},
#  'Canada': {'B2G': 1, 'count': 1},
#  'City,': {'Utah': 1, 'count': 1},
#  'Cross-sectional,': {'case-control,': 1, 'count': 1},
#  'DESIGN.': {'Cross-sectional,': 1, 'count': 1},
#  'Daley,': {'K.': 1, 'count': 1},
#  'DeMont,': {'M.E.': 1, 'count': 1},
#  'Department': {'count': 12, 'of': 12},
#  'Department,': {'St': 1, 'count': 1},
#  'Describe': {'count': 2, 'methodological': 1, 'the': 1},
#  'Dietary': {'count': 1, 'supplementation': 1},
#  'Dunedin': {'9001,': 3, 'count': 3},
#  'Dunedin,': {'New': 3, 'count': 3},
#  'Editorial': {'%A': 1, 'count': 1},
#  'Education,': {'The': 1, 'University': 5, 'count': 6},
#  'Effects': {'count': 1, 'of': 1},
#  'Email:': {'count': 13,
#   'drsquat=AT=issaonline.com': 1,
#   'edemont=AT=juliet.stfx.ca': 1,
#   'fkatch=AT=excsci.umass.edu': 1,
#   'kdaley=AT=mum.edu': 1,
#   'kreider.richard=AT=coe.memphis.edu': 1,
#   'lburke=AT=ausport.gov.au': 1,
#   'rnicholson=AT=pooka.otago.ac.nz': 1,
#   'will.hopkins=AT=otago.ac.nz': 5,
#   'wmasands=AT=concentric.net': 1},
#  'Exercise': {'&': 2, 'Science,': 1, 'and': 1, 'count': 4},
#  'F.C.': {'%T': 1, 'count': 1},
#  'F.I.': {'%T': 1, 'count': 1},
#  'FINDINGS.': {'Dietary': 1, 'Write': 1, 'count': 2},
#  'FURTHER': {'RESEARCH.': 2, 'count': 2},
#  'Fairfield,': {'Iowa,': 1, 'count': 1},
#  'Fluid': {'and': 1, 'count': 1},
#  'For': {'an': 1, 'count': 2, 'example:': 1},
#  'Forum': {'contributors': 1, 'count': 1},
#  'Francis': {'Xavier': 1, 'count': 1},
#  'Give': {'count': 1, 'data': 1},
#  'Guidelines': {'count': 1, 'on': 1},
#  'HMB,': {'count': 1, 'hydroxymethylbutyrate,': 1},
#  'Hatfield,': {'F.C.': 1, 'count': 1},
#  'Hawley,': {'J.A.': 1, 'count': 1},
#  'History': {'Makers:': 1, 'count': 1},
#  'Hopkins,': {'W.G.': 5, 'count': 5},
#  'How': {'count': 2, 'to': 2},
#  'However,': {'count': 1, 'the': 1},
#  'Human': {'Biology': 1, 'Movement': 1, 'count': 3, 'judges': 1},
#  'I': {'also': 1, 'count': 2, 'present': 1},
#  'In': {'a': 1, 'count': 5, 'one': 1, 'the': 1, 'this': 2},
#  'Include': {'any': 1, 'count': 1},
#  'Indicate': {'count': 1, 'what': 1},
#  'Ingesting': {'carbohydrate': 1, 'count': 1},
#  'Institute': {'count': 2, 'of': 2},
#  'International': {'Sports': 1, 'count': 1},
#  'Internet,': {'count': 1, 'kinesiology,': 1},
#  'Interpret': {'count': 1, 'the': 1},
#  'Iowa,': {'USA': 1, 'count': 1},
#  'J.A.': {'%A': 1, 'count': 1},
#  'J.R.': {'%T': 1, 'count': 1},
#  'Journal': {'Article': 13, 'count': 13},
#  'Judging': {'count': 1, 'gymnastics': 1},
#  'K.': {'%T': 1, 'count': 1},
#  'Katch,': {'F.I.': 1, 'count': 1},
#  'Kreider,': {'R.B.': 1, 'count': 1},
#  'L.M.': {'%T': 2, 'count': 2},
#  'LITERATURE.': {'List': 1, 'Two': 1, 'count': 2},
#  'Laboratory,': {'Department': 1, 'count': 1},
#  'Lake': {'City,': 1, 'count': 1},
#  'Learn': {'count': 1, 'from': 1},
#  'List': {'count': 2, 'the': 2},
#  'M.E.': {'%T': 1, 'count': 1},
#  'MEASURES.': {'List': 1, 'count': 1},
#  'Maharishi': {'University': 1, 'count': 1},
#  'Makers:': {'Wilbur': 1, 'count': 1},
#  'Management,': {'Fairfield,': 1, 'count': 1},
#  'Maryland,': {'USA': 1, 'count': 1},
#  'Massachusetts,': {'Amherst,': 1, 'count': 1},
#  'McNeil,': {'J.R.': 1, 'count': 1},
#  'Measuring': {'count': 1, 'enhancements': 1},
#  'Memphis,': {'Memphis,': 1, 'Tennessee': 1, 'count': 2},
#  'Most': {'count': 1, 'studies': 1},
#  'Movement': {'Science,': 1, 'Sciences': 1, 'count': 2},
#  'Moving': {'Together:': 1, 'count': 1},
#  "Nature's": {'competitive': 1, 'count': 1},
#  'New': {'Zealand': 3, 'Zealand.': 3, 'count': 6},
#  'News': {'%A': 5, 'count': 5},
#  'Newsletter': {'23': 1, 'count': 1},
#  'Nicholson,': {'R.M.': 1, 'count': 1},
#  'Nova': {'Scotia,': 1, 'count': 1},
#  'Nutrition': {'Laboratory,': 1, 'count': 1},
#  'Nutrition,': {'Australian': 2, 'count': 2},
#  'OUTCOMES.': {'State': 1, 'count': 1},
#  'Of': {'count': 1, 'the': 1},
#  'Olin': {'Atwater': 1, 'count': 1},
#  'Olympic': {'count': 1, 'weightlifting,': 1},
#  'Otago,': {'Dunedin': 3, 'Dunedin,': 3, 'count': 6},
#  'Perspective': {'%A': 6, 'count': 6},
#  'Physical': {'Education,': 5, 'count': 5},
#  'Physiology': {'and': 4, 'count': 4},
#  'Physiology,': {'University': 1, 'count': 1},
#  'Protein': {'and': 1, 'count': 1},
#  'Psychological': {'Association.': 1, 'count': 1},
#  'R.B.': {'%T': 1, 'count': 1},
#  'R.M.': {'%T': 1, 'count': 1},
#  'RESEARCH.': {'All': 1, 'Indicate': 1, 'count': 2},
#  'RMIT': {'University,': 1, 'count': 1},
#  'Recent': {'count': 1, 'work': 1},
#  'Researching': {'count': 1, 'worthwhile': 1},
#  'Review': {'%A': 1, 'count': 1},
#  'SUBJECTS.': {'State': 1, 'count': 1},
#  'Salt': {'Lake': 1, 'count': 1},
#  'Sands,': {'W.A.': 1, 'count': 1},
#  'Santa': {'Barbara,': 1, 'count': 1},
#  'School': {'count': 5, 'of': 5},
#  'Science,': {'RMIT': 1, 'University': 2, 'count': 3},
#  'Sciences': {'&': 1, 'Association,': 1, 'count': 2},
#  'Sciences,': {'Maharishi': 1, 'count': 1},
#  'Scotia,': {'Canada': 1, 'count': 1},
#  'Some': {'count': 1, 'trainers': 1},
#  'Sport': {'Nutrition': 1, 'Science,': 1, 'Sciences,': 1, 'count': 3},
#  'Sport,': {'Belconnen': 2, 'count': 2},
#  'Sports': {'Nutrition,': 2, 'Sciences': 1, 'count': 3},
#  'Sportsci': {'%B': 13, 'count': 13},
#  'Sportscience': {'%V': 13, 'Forum': 1, 'count': 15, 'sets': 1},
#  'Sportscience,': {'a': 1, 'count': 1},
#  'St': {'Francis': 1, 'count': 1},
#  'State': {'count': 2, 'the': 1, 'them': 1},
#  'Summary': {'count': 1, 'should': 1},
#  'Summary,': {'count': 1, 'get': 1},
#  'Supplementation': {'count': 1, 'with': 1},
#  'TECHNICALITIES.': {'Describe': 1, 'count': 1},
#  'Technology': {'and': 1, 'count': 1},
#  'Tennessee': {'38152.': 1, 'count': 1},
#  'The': {'University': 1,
#   'count': 11,
#   'dominant': 1,
#   'effects': 1,
#   'guidelines': 1,
#   'lack': 1,
#   'machine': 1,
#   'objective': 1,
#   'power': 1,
#   'second': 1,
#   'summary': 2},
#  'There': {'count': 1, 'is': 1},
#  'These': {'count': 1, 'forces': 1},
#  'They': {'also': 1, 'count': 1},
#  'This': {'count': 2, 'review': 1, 'section': 1},
#  'To': {'avoid': 1, 'count': 2, 'determine': 1},
#  'Together:': {'Newsletter': 1, 'count': 1},
#  'Topics': {'count': 1, 'in': 1},
#  'Try': {'count': 1, 'to': 1},
#  'Two': {'books,': 1, 'count': 2, 'examples': 1},
#  'USA': {'01003.': 1, '52557.': 1, 'count': 2},
#  'University': {'count': 10, 'of': 10},
#  'University,': {'Antigonish,': 1, 'Bundoora': 1, 'count': 2},
#  'Until': {'count': 1, 'there': 1},
#  'Use': {'count': 1, 'plain': 1},
#  'Utah': {'84112.': 1, 'count': 1},
#  'Utah,': {'Salt': 1, 'count': 1},
#  'W.A.': {'%A': 1, 'count': 1},
#  'W.G.': {'%A': 1, '%T': 4, 'count': 5},
#  'We': {'combined': 1, 'count': 2, 'have': 1},
#  'Web': {'%0': 1, 'count': 1},
#  'Whether': {'count': 2, 'employing': 1, 'it': 1},
#  'Wilbur': {'Olin': 1, 'count': 1},
#  'Write': {'count': 1, 'several': 1},
#  'X': {'and': 1, 'count': 2, 'on': 1},
#  'Xavier': {'University,': 1, 'count': 1},
#  'Y,': {'and': 1, 'count': 2, 'the': 1},
#  'Zealand': {'9001.': 3, 'count': 3},
#  'Zealand.': {'Email:': 3, 'count': 3},
#  'a': {'competition.': 1,
#   'computer': 1,
#   'conclusion': 1,
#   'count': 18,
#   'descriptive': 1,
#   'difference': 1,
#   'full': 1,
#   'human': 1,
#   'literature': 1,
#   'more': 1,
#   'new': 1,
#   'performance': 1,
#   'recent': 1,
#   'repeated-measures': 1,
#   'research': 1,
#   'sentence': 2,
#   'team': 1,
#   'trial': 1},
#  'abbreviations': {'count': 1, 'through': 1},
#  'abbreviations.': {'CONCLUSIONS.': 1, 'count': 1},
#  'about': {'count': 1, 'half': 1},
#  'abstracts,': {'and': 1, 'count': 1},
#  'accurately': {'count': 1, 'in': 1},
#  'acids': {'(e.g.,': 1, '(leucine,': 1, 'are': 1, 'count': 4, 'enhances': 1},
#  'acids,': {'branched-chain': 1, 'count': 3, 'creatine,': 1, 'glutamine,': 1},
#  'adaptations': {'count': 2, 'in': 1, 'to': 1},
#  'additional': {'benefits': 1, 'count': 1},
#  'adequate': {'count': 1, 'precision': 1},
#  'adjustable': {'count': 1, 'resistance': 1},
#  'advice': {'based': 1, 'count': 2, 'should': 1},
#  'affects': {'count': 1, 'training': 1},
#  'agreed': {'count': 2, 'that': 2},
#  'air-water': {'count': 1, 'interface': 1},
#  'algorithm.': {'We': 1, 'count': 1},
#  'allows': {'count': 1, 'the': 1},
#  'also': {'agreed': 1, 'count': 2, 'deal': 1},
#  'amino': {'acids': 4, 'acids,': 3, 'count': 7},
#  'amino-acid': {'count': 1, 'supplementation': 1},
#  'among': {'count': 1, 'the': 1},
#  'an': {'athlete': 1,
#   'count': 5,
#   'effective': 1,
#   'endurance': 1,
#   'important': 1,
#   'objective': 1},
#  'anabolic': {'amino': 1, 'count': 3, 'effects': 1, 'hormonal': 1},
#  'anabolic,': {'BCAA,': 1, 'count': 1},
#  'analysis': {'%0': 1, 'count': 1},
#  'analysis,': {'count': 2, 'design,': 2},
#  'and': {'19': 1,
#   'School': 4,
#   'Sport': 1,
#   'Y,': 1,
#   'a': 1,
#   'abbreviations': 1,
#   'amino': 1,
#   'amino-acid': 1,
#   'analysis': 1,
#   'bibliographic': 1,
#   'carbohydrate': 2,
#   'citation': 1,
#   'count': 44,
#   'dead': 1,
#   'downloadable': 1,
#   'effects': 1,
#   'energy': 1,
#   'experience.': 1,
#   'explain': 1,
#   'fat-free': 1,
#   'glutamine': 1,
#   'hydroxymethylbutyrate': 1,
#   'immune': 1,
#   'increase': 1,
#   'interpret': 1,
#   'no': 1,
#   'phenylalanine)': 1,
#   'potential': 1,
#   'power': 1,
#   'recommendations': 1,
#   'safe': 1,
#   'so': 2,
#   'speed': 1,
#   'standard': 1,
#   'statistics,': 1,
#   'teaching': 1,
#   'the': 1,
#   'to': 1,
#   'valine)': 1,
#   'with': 1},
#  'and/or': {'count': 1, 'glucocorticoids,': 1},
#  'animal': {'count': 1, 'locomotion': 1},
#  'animals': {'can': 1, 'count': 2, 'that': 1},
#  'any': {'count': 3, 'major': 1, 'point': 1, 'relevant': 1},
#  'appears': {'count': 2, 'to': 2},
#  'appropriate': {'count': 1, 'demographics.': 1},
#  'aquatic': {'animal': 1, 'animals': 1, 'count': 2},
#  'are': {'among': 1,
#   'available': 1,
#   'better': 1,
#   'count': 8,
#   'effective': 1,
#   'generally': 1,
#   'hard': 1,
#   'important.': 1,
#   'uncertain,': 1},
#  'arginine,': {'count': 1, 'histidine,': 1},
#  'argument': {'count': 1, 'on': 1},
#  'arise': {'count': 1, 'from': 1},
#  'article': {'I': 1, 'count': 2, 'templates,': 1},
#  'articles': {'count': 1, 'or': 1},
#  'articles,': {'10': 1, 'comprehensible': 1, 'count': 3, 'one': 1},
#  'as': {'count': 6,
#   'economical': 2,
#   'possible,': 2,
#   'supplements': 1,
#   'yet,': 1},
#  'at': {'a': 1, 'any': 1, 'count': 4, 'present.': 1, 'the': 1},
#  'athlete': {'at': 1, 'count': 1},
#  "athlete's": {'count': 1, 'typical': 1},
#  'athlete.': {'Some': 1, 'count': 1},
#  'athletes': {'count': 3, 'involved': 1, 'or': 1, 'should': 1},
#  'athletes,': {'count': 1, 'exercise': 1},
#  'athletes.': {'CONCLUSIONS.': 1,
#   'However,': 1,
#   'Ingesting': 1,
#   'This': 1,
#   'count': 4},
#  'athletic': {'caliber,': 1, 'count': 5, 'performance': 2, 'performance.': 2},
#  'available': {'count': 1, 'to': 1},
#  'avoid': {'confusion': 1, 'count': 1},
#  'balance': {'count': 1, 'does': 1},
#  'based': {'count': 1, 'on': 1},
#  'be': {'an': 1,
#   'count': 8,
#   'done.': 1,
#   'due': 1,
#   'involved': 1,
#   'reevaluated.': 1,
#   'seen.': 1,
#   'taught': 1,
#   'tempered': 1},
#  'because': {'changes': 1, 'count': 1},
#  'benefit': {'count': 1, 'research': 1},
#  'benefits': {'count': 1, 'for': 1},
#  'better': {'count': 1, 'research': 1},
#  'between': {'X': 1,
#   'athletes': 1,
#   'competitors': 1,
#   'count': 5,
#   'performances': 1,
#   'studies.': 1},
#  'between-event': {'count': 1, 'variation': 1},
#  'beyond': {'count': 1, 'that': 1},
#  'bibliographic': {'count': 1, 'files.': 1},
#  'bigger': {'count': 1, 'sample': 1},
#  'biomechanics': {'%J': 1, 'count': 1},
#  'biomechanics,': {'count': 1, 'drag,': 1},
#  'biomechanists': {'count': 1, 'studying': 1},
#  'book': {'chapters.': 1, 'count': 1},
#  'books,': {'61': 1, 'count': 1},
#  'branched-chain': {'amino': 2, 'count': 2},
#  'but': {'count': 5, 'do': 2, 'the': 1, 'their': 1, 'there': 1},
#  'by': {'athletes.': 1,
#   'common': 1,
#   'comparative': 1,
#   'competitive': 1,
#   'count': 8,
#   'optimizing': 1,
#   'stimulating': 1,
#   'the': 1,
#   'using': 1},
#  'caliber,': {'and': 1, 'count': 1},
#  'calorimetry,': {'count': 1, 'exercise': 1},
#  'can': {'benefit': 1, 'count': 1},
#  'carbohydrate': {'count': 3, 'feeding': 1, 'intake': 1, 'with': 1},
#  'case-control,': {'count': 1, 'randomized': 1},
#  'catabolism': {'and': 1, 'count': 1},
#  'catabolism,': {'count': 1, 'promote': 1},
#  'central': {'count': 1, 'fatigue': 1},
#  'certain': {'amino': 1, 'count': 1},
#  'chance': {'count': 1, 'of': 1},
#  'change': {'count': 1, 'resistance': 1},
#  'changes': {'count': 1, 'in': 1},
#  'chapters.': {'FINDINGS.': 1, 'count': 1},
#  'citation': {'count': 1, 'of': 1},
#  'clean': {'(hang': 1, 'and': 1, 'count': 3, 'vs': 1},
#  'clean,': {'Olympic': 1, 'count': 1},
#  'cleans': {'and': 1, 'count': 1},
#  'clear.': {'There': 1, 'count': 1},
#  'clinical': {'count': 1, 'studies': 1},
#  'combined': {'count': 1, 'the': 1},
#  'common': {'count': 3, 'grammatical': 1, 'nutritional': 1, 'sense': 1},
#  'comparative': {'biomechanists': 1, 'count': 1},
#  'competition.': {'%K': 1, 'count': 1},
#  'competitions,': {'count': 1, 'elite': 1},
#  'competitive': {'count': 4, 'performance,': 1, 'swimmers': 3},
#  'competitors': {'count': 1, 'in': 1},
#  'components': {'count': 1, 'of': 1},
#  'comprehensible': {'count': 1, 'data': 1},
#  'compromise': {'count': 2, 'grammar.': 2},
#  'compulsory': {'count': 1, 'vault': 1},
#  'computer': {'algorithm.': 1, 'count': 1},
#  'conclusion': {'count': 1, 'of': 1},
#  'conditions': {'between': 1, 'count': 1},
#  'conferences,': {'count': 1, 'lecture': 1},
#  'confusion': {'count': 1, 'over': 1},
#  'considerably': {'count': 1, 'from': 1},
#  'consist': {'count': 2, 'of': 2},
#  'consistency': {'count': 1, 'in': 1},
#  'consistent': {'count': 1, 'with': 1},
#  'content': {'count': 1, 'through': 1},
#  'continue': {'count': 1, 'to': 1},
#  'contributes': {'count': 1, 'to': 1},
#  'contributors': {'agreed': 1, 'count': 1},
#  'controlled': {'count': 1, 'trial,': 1},
#  'creates': {'count': 1, 'unsteady': 1},
#  'creatine': {'appears': 1, 'count': 2, 'supplementation': 1},
#  'creatine,': {'and': 1, 'count': 2, 'ergogenic,': 1},
#  'data': {'and': 2, 'are': 1, 'count': 4, 'presentation,': 1},
#  'data,': {'common': 1, 'count': 1},
#  'dead': {'count': 2, 'lift)': 1, 'lift,': 1},
#  'deal': {'count': 1, 'with': 1},
#  'decide': {'count': 1, 'how': 1},
#  'demographics.': {'MEASURES.': 1, 'count': 1},
#  'demonstrate': {'count': 1, 'how': 1},
#  'dependent': {'count': 1, 'variables': 1},
#  'depth': {'count': 2, 'during': 1, 'that': 1},
#  'descriptive': {'count': 1, 'study;': 1},
#  'design': {'and': 1, 'count': 1},
#  'design,': {'count': 3, 'publishing,': 2, 'sports': 1},
#  'determine': {'count': 1, 'the': 1},
#  'determining': {'count': 1, 'the': 1},
#  'develop': {'count': 1, 'power.': 1},
#  'deviations': {'count': 1, 'of': 1},
#  'devised': {'an': 1, 'count': 1},
#  'devoted': {'count': 1, 'to': 1},
#  'differ': {'considerably': 1, 'count': 1},
#  'difference': {'count': 1, 'to': 1},
#  'differences': {'between': 1, 'count': 3, 'in': 2},
#  'differentiation': {'between': 1, 'count': 1},
#  'difficulty': {'count': 1, 'in': 1},
#  'digitizing,': {'count': 1, 'infrared': 1},
#  'discussion': {'count': 1, 'on': 1},
#  'do': {'count': 2, 'not': 2},
#  'document.': {'I': 1, 'count': 1},
#  'documents': {'count': 2, 'you': 2},
#  'does': {'count': 1, 'not': 1},
#  'dominant': {'count': 1, 'view': 1},
#  'done.': {'The': 1, 'count': 1},
#  'double-blind': {'controlled': 1, 'count': 1},
#  'downloadable': {'article': 1, 'count': 1},
#  'drag,': {'count': 1, 'fluid': 1},
#  'drag.': {'These': 1, 'count': 1},
#  'drinks,': {'count': 1, 'supplementation,': 1},
#  'drsquat=AT=issaonline.com': {'%X': 1, 'count': 1},
#  'due': {'count': 2, 'regard': 1, 'to': 1},
#  'during': {'count': 3, 'team': 1, 'the': 1, 'training': 1},
#  'dynamically': {'adjustable': 1, 'count': 1},
#  'dynamics,': {'but': 1, 'count': 2, 'force,': 1},
#  'each': {'count': 2, 'lift': 1, 'targeted': 1},
#  'ease': {'count': 1, 'of': 1},
#  'economical': {'count': 2, 'with': 2},
#  'edemont=AT=juliet.stfx.ca': {'%X': 1, 'count': 1},
#  'education': {'%0': 1, 'count': 1},
#  'effect': {'count': 2, 'of': 2},
#  'effective': {'and': 1, 'count': 3, 'than': 1, 'ways': 1},
#  'effects': {'by': 1, 'count': 5, 'of': 2, 'on': 2},
#  'effects.': {'CONCLUSIONS.': 1, 'Use': 1, 'count': 2},
#  'elements': {'count': 1, 'of': 1},
#  'elite': {'athletes,': 1, 'count': 1},
#  'emergency': {'count': 1, 'encyclopedia,': 1},
#  'employing': {'count': 1, 'these': 1},
#  'encyclopedia,': {'count': 1, 'health-fitness...': 1},
#  'endurance': {'athletes.': 1, 'count': 2, 'event,': 1},
#  'energy': {'count': 1, 'requirements': 1},
#  'enhance': {'adaptations': 1, 'count': 2, 'performance': 1},
#  'enhancement': {'count': 1, 'makes': 1},
#  'enhancement.': {'%K': 1, 'count': 1},
#  'enhancements': {'%J': 1, 'count': 2, 'of': 1},
#  'enhances': {'athletic': 1, 'count': 2, 'performance': 1},
#  'environment.': {'Whether': 1, 'count': 1},
#  'environmental': {'conditions': 1, 'count': 1},
#  'equipment,': {'count': 1, 'strength': 1},
#  'equivocal': {'at': 1, 'count': 1},
#  'ergogenic': {'count': 2, 'potential': 1, 'value': 1},
#  'ergogenic,': {'count': 1, 'glutamine,': 1},
#  'errors,': {'and': 1, 'count': 1},
#  'errors.': {'The': 1, 'count': 1},
#  'estimates': {'count': 1, 'of': 1},
#  'evaluates': {'count': 1, 'the': 1},
#  'evaluation': {'count': 1, 'for': 1},
#  'event,': {'count': 1, 'so': 1},
#  'evidence': {'count': 2, 'from': 1, 'that': 1},
#  'example': {'contributes': 1, 'count': 1},
#  'example,': {'count': 1, 'work': 1},
#  'example:': {'31': 1, 'count': 1},
#  'examples': {'count': 1, 'demonstrate': 1},
#  'exercise': {'and': 1,
#   'count': 5,
#   'may': 1,
#   'movement.': 1,
#   'nutrition,': 1,
#   'tests,': 1},
#  'exercise-': {'count': 1, 'induced': 1},
#  'experience': {'count': 1, 'of': 1},
#  'experience.': {'%K': 1, 'count': 1},
#  'explain': {'count': 2, 'the': 1, 'why': 1},
#  'explaining': {'any': 1, 'count': 2, 'the': 1},
#  'fat-free': {'count': 1, 'mass': 1},
#  'fatigue': {'and': 1, 'count': 1},
#  'features:': {'count': 1, 'new': 1},
#  'feeding': {'count': 1, 'on': 1},
#  'field,': {'a': 1, 'count': 1},
#  'files.': {'%K': 1, 'count': 1},
#  'findings': {'count': 1, 'of': 1},
#  'findings,': {'count': 1, 'researchers': 1},
#  'first': {'count': 2, 'example,': 1, 'section': 1},
#  'five': {'count': 1, 'reviews,': 1},
#  'fkatch=AT=excsci.umass.edu': {'%K': 1, 'count': 1},
#  'flow': {'count': 1, 'of': 1},
#  'fluid': {'and': 1, 'count': 4, 'dynamics,': 2, 'motion.': 1},
#  'following': {'count': 1, 'exercise': 1},
#  'for': {'a': 2,
#   'articles,': 1,
#   'athletes': 1,
#   'athletes.': 1,
#   'competitive': 1,
#   'count': 14,
#   'form': 1,
#   'publishing': 1,
#   'safety': 1,
#   'scientific': 1,
#   'strength': 1,
#   'the': 3},
#  'force,': {'count': 1, 'lift,': 1},
#  'forces': {'arise': 1, 'count': 1},
#  'form': {'count': 1, 'errors.': 1},
#  'formal': {'count': 1, 'research': 1},
#  'four': {'count': 1, 'popular': 1},
#  'frame.': {'SUBJECTS.': 1, 'count': 1},
#  'free': {'count': 1, 'weights': 1},
#  'freestyle': {'count': 1, 'swimming.': 1},
#  'from': {"Nature's": 1,
#   'clinical': 1,
#   'count': 5,
#   'steady-state': 1,
#   'the': 1,
#   'those': 1},
#  'full': {'count': 1, 'range': 1},
#  'gains': {'count': 1, 'in': 1},
#  'game': {'count': 2, 'may': 1, 'performance.': 1},
#  'games': {'are': 1, 'count': 2, 'to': 1},
#  'games,': {'count': 1, 'or': 1},
#  'games:': {'count': 1, 'research': 1},
#  'generalizing': {'count': 1, 'to': 1},
#  'generally': {'consistent': 1, 'count': 1},
#  'generates': {'count': 1, 'more': 1},
#  'generating': {'count': 1, 'thrust,': 1},
#  'generation': {'count': 1, 'in': 1},
#  'get': {'count': 1, 'the': 1},
#  'give': {'count': 1, 'nutritional': 1},
#  'glide': {'count': 1, 'phase': 1},
#  'glucocorticoids,': {'but': 1, 'count': 1},
#  'glutamine': {'count': 1, 'may': 1},
#  'glutamine,': {'HMB,': 1, 'count': 2, 'creatine,': 1},
#  'glycogen': {'count': 1, 'resynthesis,': 1},
#  'grammar,': {'count': 1, 'punctuation,': 1},
#  'grammar.': {'%K': 2, 'count': 2},
#  'grammatical': {'count': 1, 'errors,': 1},
#  'greatest': {'count': 1, 'ergogenic': 1},
#  'grounds': {'count': 1, 'of': 1},
#  'growth': {'count': 1, 'hormone,': 1},
#  'guidelines': {'are': 1, 'count': 1},
#  'gym': {'count': 1, 'equipment,': 1},
#  'gymnastics': {'count': 1, 'with': 1},
#  'gymnastics.': {'We': 1, 'count': 1},
#  'gymnasts': {'at': 1, 'count': 1},
#  'half': {'count': 1, 'the': 1},
#  'hang': {'clean,': 1, 'count': 1},
#  'hard': {'count': 1, 'to': 1},
#  'has': {'count': 3, 'shown': 2, 'the': 1},
#  'have': {'anabolic': 1,
#   'count': 5,
#   'devised': 1,
#   'difficulty': 1,
#   'the': 1,
#   'used': 1},
#  'health-fitness...': {'%K': 1, 'count': 1},
#  'here': {'count': 2, 'need': 1, 'to': 1},
#  'high-intensity': {'count': 1, 'exercise': 1},
#  'histidine,': {'count': 1, 'lysine,': 1},
#  'hormonal': {'count': 1, 'environment.': 1},
#  'hormone,': {'count': 1, 'insulin,': 1},
#  'how': {'count': 2, 'it': 1, 'research': 1},
#  'human': {'count': 2, "judge's": 1, 'swimmers.': 1},
#  'hydration': {'count': 1, 'status': 1},
#  'hydroxymethylbutyrate': {'(HMB).': 1, 'appears': 1, 'count': 2},
#  'hydroxymethylbutyrate,': {'count': 1, 'training': 1},
#  'ideas': {'count': 1, 'in': 1},
#  'if': {'count': 2, 'they': 2},
#  'immune': {'count': 1, 'suppression,': 1},
#  'important': {'count': 1, 'role': 1},
#  'important.': {'AIM.': 1, 'OUTCOMES.': 1, 'count': 2},
#  'improve': {'count': 1, 'strength': 1},
#  'in': {'a': 2,
#   'athletes.': 1,
#   'count': 28,
#   'determining': 1,
#   'each': 1,
#   'environmental': 1,
#   'exercise-': 1,
#   'freestyle': 1,
#   'generalizing': 1,
#   'generating': 1,
#   'gymnastics.': 1,
#   'intense': 1,
#   'performance': 1,
#   'performance.': 1,
#   'strength': 1,
#   'team': 1,
#   'the': 6,
#   'these': 1,
#   'this': 3,
#   'trajectories': 1,
#   'untrained': 1},
#  'include': {'a': 1, 'count': 1},
#  'included': {'count': 1, 'in': 1},
#  'increase': {'count': 1, 'gains': 1},
#  'increased': {'count': 1, 'the': 1},
#  'indicate': {'count': 1, 'that': 1},
#  'individuals': {'count': 1, 'initiating': 1},
#  'induced': {'central': 1, 'count': 1},
#  'infrared': {'count': 1, 'timers,': 1},
#  'initiating': {'count': 1, 'training;': 1},
#  'innovative': {'count': 1, 'features:': 1},
#  'insights': {'count': 1, 'in': 1},
#  'instantly': {'change': 1, 'count': 1},
#  'insulin,': {'and/or': 1, 'count': 1},
#  'intake': {'count': 1, 'during': 1},
#  'intense': {'count': 1, 'training.': 1},
#  'interest': {'count': 1, 'with': 1},
#  'interface': {'count': 1, 'has': 1},
#  'intermittent': {'count': 1, 'high-intensity': 1},
#  'interpret': {'count': 1, 'magnitudes': 1},
#  'interpretation': {'count': 1, 'of': 1},
#  'intervention,': {'count': 1, 'or': 1},
#  'investigations,': {'count': 1, 'one': 1},
#  'involved': {'count': 3, 'in': 3},
#  'is': {'about': 1,
#   'count': 9,
#   'equivocal': 1,
#   'important.': 1,
#   'little': 1,
#   'more': 1,
#   'not': 1,
#   'some': 1,
#   'that': 1,
#   'the': 1},
#  'isoleucine,': {'and': 1, 'count': 1},
#  'it': {'affects': 1, 'count': 3, 'is': 2},
#  'journal,': {'count': 2, 'offers': 1, 'peer-review,': 1},
#  "judge's": {'count': 1, 'score': 1},
#  'judge,': {'count': 1, 'score,': 1},
#  'judges': {'count': 1, 'often': 1},
#  'kdaley=AT=mum.edu': {'%X': 1, 'count': 1},
#  'kinesiology,': {'count': 1, 'news,': 1},
#  'kreider.richard=AT=coe.memphis.edu': {'%X': 1, 'count': 1},
#  'lab': {'count': 1, 'tests,': 1},
#  'lack': {'count': 2, 'of': 2},
#  'language': {'and': 1, 'count': 1},
#  'lburke=AT=ausport.gov.au': {'%X': 1, 'count': 1},
#  'lecture': {'count': 1, 'notes,': 1},
#  'less': {'count': 2, 'than': 2},
#  'lesson': {'count': 1, 'plans,': 1},
#  'lift': {'count': 2, 'generates': 1, 'need': 1},
#  'lift)': {'count': 1, 'on': 1},
#  'lift,': {'count': 2, 'hang': 1, 'swim,': 1},
#  'likely': {'count': 1, 'ranges': 1},
#  'limitations': {'count': 1, 'in': 1},
#  'limited': {'count': 1, 'data': 1},
#  'list': {'count': 1, 'the': 1},
#  'literature': {'count': 1, 'review': 1},
#  'little': {'count': 1, 'evidence': 1},
#  'locomotion': {'count': 1, 'has': 1},
#  'lysine,': {'count': 1, 'methionine,': 1},
#  'machine': {'allows': 1, 'count': 3, 'has': 1, 'with': 1},
#  'machines': {'count': 1, 'or': 1},
#  'magnitude': {'count': 1, 'with': 1},
#  'magnitudes': {'count': 1, 'of': 1},
#  'main': {'count': 2, 'findings': 1, 'variables': 1},
#  'maintain': {'count': 1, 'nitrogen': 1},
#  'major': {'count': 1, 'limitations': 1},
#  'makes': {'a': 1, 'count': 1},
#  'manuscript.': {'FINDINGS.': 1, 'count': 1},
#  'many': {'count': 1, 'innovative': 1},
#  'mass': {'count': 1, 'in': 1},
#  'maximum': {'count': 1, 'stress.': 1},
#  'may': {'be': 3, 'count': 5, 'differ': 1, 'reduce': 1},
#  'means': {'and': 1, 'count': 1},
#  'measure': {'accurately': 1, 'count': 2, 'the': 1},
#  'measurement': {'count': 1, 'of': 1},
#  'mechanisms': {'count': 2, 'probably': 1, 'used': 1},
#  'medical': {'count': 1, 'emergency': 1},
#  'metabolism': {'%0': 1, 'count': 1},
#  'methionine,': {'count': 1, 'ornithine,': 1},
#  'methodological': {'count': 1, 'problems': 1},
#  'minimizes': {'count': 1, 'surface': 1},
#  'monograph,': {'count': 1, 'five': 1},
#  'more': {'anabolic': 1,
#   'count': 4,
#   'effective': 1,
#   'evaluation': 1,
#   'thrust': 1},
#  'most': {'common': 1, 'count': 1},
#  'motion.': {'Recent': 1, 'count': 1},
#  'motion;': {'and': 1, 'count': 1},
#  'move': {'count': 1, 'through': 1},
#  'movement': {'count': 1, 'of': 1},
#  'movement.': {'The': 1, 'count': 1},
#  'much': {'bigger': 1, 'count': 1},
#  'muscle': {'count': 1, 'spends': 1},
#  'must': {'consist': 2, 'count': 2},
#  'nature': {'count': 1, 'of': 1},
#  'necessary': {'count': 1, 'to': 1},
#  'need': {'count': 4, 'for': 1, 'more': 1, 'only': 1, 'to': 1},
#  'needs': {'count': 1, 'to': 1},
#  'new': {'count': 4,
#   'quarterly': 1,
#   'strength-training': 1,
#   'structures': 1,
#   'weights': 1},
#  'news,': {'count': 1, 'physical': 1},
#  'newsletter:': {'Technology': 1, 'count': 1},
#  'nitrogen': {'balance': 1, 'count': 1},
#  'no': {'abbreviations.': 1, 'count': 1},
#  'normally': {'count': 1, 'use.': 1},
#  'not': {'compromise': 2, 'count': 4, 'provide': 1, 'yet': 1},
#  'notes,': {'count': 1, 'lesson': 1},
#  'now': {'count': 1, 'needs': 1},
#  'number': {'count': 2, 'of': 2},
#  'nutrients': {'count': 1, 'reviewed,': 1},
#  'nutrition,': {'count': 2, 'metabolism': 1, 'research': 1},
#  'nutritional': {'advice': 1,
#   'count': 4,
#   'intervention,': 1,
#   'strategies': 1,
#   'supplements': 1},
#  'objective': {'count': 3, 'score': 2, 'scoring': 1},
#  'of': {'25': 1,
#   'Exercise': 3,
#   'Human': 2,
#   'Management,': 1,
#   'Massachusetts,': 1,
#   'Memphis,': 1,
#   'Otago,': 6,
#   'Physical': 5,
#   'Physiology': 4,
#   'Physiology,': 1,
#   'Sport,': 2,
#   'Sports': 2,
#   'Utah,': 1,
#   'X': 1,
#   'an': 1,
#   'consistency': 1,
#   'count': 73,
#   'data,': 1,
#   'effects.': 1,
#   'growth': 1,
#   'hydration': 1,
#   'ideas': 1,
#   'intermittent': 1,
#   'less': 2,
#   'motion;': 1,
#   'nutritional': 1,
#   'performance': 1,
#   'performance,': 1,
#   'practical': 1,
#   'precision': 1,
#   'protein': 2,
#   'protein,': 1,
#   'publications.': 1,
#   'punctuation': 1,
#   'researchers': 1,
#   'scientific': 1,
#   'sport': 1,
#   'subjects,': 1,
#   'teaching.': 1,
#   'the': 8,
#   'their': 3,
#   'these': 2,
#   'this': 1,
#   'thrust': 1,
#   'winning': 1},
#  'offers': {'count': 1, 'many': 1},
#  'often': {'count': 1, 'have': 1},
#  'on': {'Y,': 1,
#   'aquatic': 2,
#   'athletic': 3,
#   'count': 14,
#   'human': 1,
#   'performance': 1,
#   'research': 1,
#   'simulated': 1,
#   'style': 1,
#   'the': 3},
#  'on.': {'DESIGN.': 1, 'Include': 1, 'count': 2},
#  'one': {'count': 3, 'manuscript.': 1, 'monograph,': 1, 'or': 1},
#  'ongoing': {'argument': 1, 'count': 1},
#  'only': {'a': 1, 'count': 3, 'if': 2},
#  'optimal': {'count': 1, 'depth': 1},
#  'optimizing': {'count': 1, 'the': 1},
#  'or': {'book': 1,
#   'count': 13,
#   'differences': 1,
#   'ease': 1,
#   'following': 1,
#   'free': 1,
#   'insights': 1,
#   'promote': 1,
#   'real': 1,
#   'sports': 1,
#   'the': 1,
#   'two': 2,
#   'two.': 1},
#  'original': {'count': 1, 'investigations,': 1},
#  'ornithine,': {'and': 1, 'count': 1},
#  'other': {'components': 1, 'count': 2, 'machines': 1},
#  'outcomes': {'count': 2, 'of': 1, 'qualitatively,': 1},
#  'outline': {'count': 1, 'the': 1},
#  'over': {'count': 1, 'interpretation': 1},
#  'pace': {'count': 1, 'for': 1},
#  'paper': {'%J': 1, 'count': 1},
#  'papers,': {'and': 1, 'count': 1},
#  'peer-review,': {'count': 1, 'sport': 1},
#  'performance': {'%J': 1,
#   'are': 1,
#   'count': 9,
#   'enhancement': 1,
#   'enhancement.': 1,
#   'enhancements': 1,
#   'in': 1,
#   'is': 1,
#   'of': 2},
#  'performance,': {'count': 2, 'differences': 1, 'judge,': 1},
#  'performance.': {'%K': 1,
#   'Branched-chain': 1,
#   'Measuring': 1,
#   'The': 1,
#   'count': 4},
#  'performances': {'count': 1, 'in': 1},
#  'phase': {'count': 1, 'is': 1},
#  'phenylalanine)': {'count': 1, 'have': 1},
#  'physical': {'count': 1, 'education': 1},
#  'plain': {'count': 1, 'language': 1},
#  'plans,': {'count': 1, 'medical': 1},
#  'play': {'an': 1, 'count': 1},
#  'point': {'count': 1, 'in': 1},
#  'popular': {'articles,': 1, 'content': 1, 'count': 2},
#  'populations.': {'The': 1, 'count': 1},
#  'possible,': {'but': 2, 'count': 2},
#  'potential': {'count': 3, 'effects': 1, 'for': 1, 'to': 1},
#  'power': {'clean': 2,
#   'cleans': 1,
#   'count': 7,
#   'pull': 2,
#   'pulls': 1,
#   'shrug,': 1},
#  'power.': {'They': 1, 'count': 1},
#  'practical': {'count': 1, 'significance.': 1},
#  'precision': {'count': 3, 'in': 1, 'of': 1, 'requires': 1},
#  'preferred': {'count': 1, 'the': 1},
#  'present': {'count': 1, 'the': 1},
#  'present.': {'Most': 1, 'count': 1},
#  'presentation': {'count': 1, 'of': 1},
#  'presentation,': {'count': 1, 'grammar,': 1},
#  'prior': {'count': 1, 'to': 1},
#  'probably': {'count': 1, 'play': 1},
#  'problems': {'count': 1, 'or': 1},
#  'procedures': {'count': 1, 'in': 1},
#  'progressively,': {'count': 1, 'through': 1},
#  'promote': {'a': 1, 'count': 2, 'glycogen': 1},
#  'promoted': {'by': 1, 'count': 1},
#  'protein': {'and': 1, 'beyond': 1, 'count': 3, 'prior': 1},
#  'protein,': {'count': 1, 'purported': 1},
#  'provide': {'additional': 1, 'count': 1},
#  'publications.': {'The': 1, 'count': 1},
#  'publish': {'and': 1, 'count': 1},
#  'published': {'abstracts,': 1, 'count': 1},
#  'publishing': {'count': 1, 'sport': 1},
#  'publishing,': {'count': 3, 'research': 1, 'research,': 2},
#  'pull': {'count': 2, 'for': 1, 'or': 1},
#  'pulls': {'are': 1, 'count': 1},
#  'punctuation': {'and': 1, 'count': 1},
#  'punctuation,': {'count': 1, 'publishing,': 1},
#  'purported': {'anabolic': 1, 'count': 1},
#  'qualitatively,': {'count': 1, 'explaining': 1},
#  'quantitatively,': {'count': 1, 'with': 1},
#  'quarterly': {'count': 1, 'journal,': 1},
#  'randomized': {'count': 1, 'double-blind': 1},
#  'range': {'count': 1, 'of': 1},
#  'ranges': {'count': 1, 'for': 1},
#  'ranging': {'count': 1, 'from': 1},
#  'rationale': {'and': 1, 'count': 1},
#  "reader's": {'count': 1, 'interest': 1},
#  'real': {'count': 2, 'games': 1, 'populations.': 1},
#  'recent': {'count': 1, 'discussion': 1},
#  'recommendations': {'%J': 1, 'count': 1},
#  'reduce': {'catabolism': 1, 'catabolism,': 1, 'count': 2},
#  'reevaluated.': {'%K': 1, 'count': 1},
#  'regard': {'count': 1, 'to': 1},
#  'relationship': {'between': 1, 'count': 1},
#  'release': {'count': 1, 'of': 1},
#  'relevant': {'count': 1, 'time': 1},
#  'remains': {'count': 1, 'to': 1},
#  'repeated-measures': {'count': 1, 'study.': 1},
#  'reprints,': {'and': 1, 'count': 1},
#  'requirements': {'count': 1, 'in': 1},
#  'requires': {'count': 1, 'much': 1},
#  'research': {'%0': 1,
#   '%J': 1,
#   'and': 1,
#   'articles,': 1,
#   'count': 12,
#   'design': 1,
#   'design,': 1,
#   'on': 2,
#   'paper': 1,
#   'papers,': 1,
#   'tools,': 1,
#   'with': 1},
#  'research,': {'count': 2, 'scientific': 2},
#  'researchers': {'count': 3, 'have': 1, 'normally': 1, 'should': 1},
#  'resistance': {'%J': 1, 'at': 1, 'count': 2},
#  'resynthesis,': {'count': 1, 'or': 1},
#  'review': {'%J': 1, 'articles': 1, 'count': 3, 'evaluates': 1},
#  'review.': {'For': 1, 'LITERATURE.': 1, 'count': 2},
#  'reviewed': {'count': 1, 'here': 1},
#  'reviewed,': {'count': 1, 'creatine': 1},
#  'reviewed.': {'Give': 1, 'count': 1},
#  'reviews,': {'count': 1, 'four': 1},
#  'rnicholson=AT=pooka.otago.ac.nz': {'%X': 1, 'count': 1},
#  'role': {'count': 1, 'in': 1},
#  'safe': {'count': 1, 'way': 1},
#  'safety': {'and': 1, 'count': 1},
#  'sample': {'count': 1, 'sizes': 1},
#  'science,': {'Web': 1, 'count': 1},
#  'scientific': {'count': 4, 'style,': 1, 'writing': 3},
#  'score': {'count': 3, 'for': 1, 'successfully': 1, 'with': 1},
#  'score,': {'count': 1, 'skill,': 1},
#  'scoring': {'count': 1, 'system': 1},
#  'second': {'count': 1, 'example': 1},
#  'section': {'count': 2, 'of': 2},
#  'sections': {'count': 1, 'devoted': 1},
#  'seen.': {'%K': 1, 'count': 1},
#  'sense': {'and': 1, 'count': 1},
#  'sentence': {'count': 2, 'or': 2},
#  'sentences': {'count': 2, 'explain': 1, 'here': 1},
#  'sets': {'count': 1, 'the': 1},
#  'several': {'count': 1, 'sentences': 1},
#  'should': {'be': 2, 'continue': 1, 'count': 5, 'need': 1, 'therefore': 1},
#  'shown': {'count': 2, 'that': 2},
#  'shrug,': {'count': 1, 'specificity': 1},
#  'significance.': {'FURTHER': 1, 'count': 1},
#  'simulated': {'count': 2, 'game': 1, 'games,': 1},
#  'sizes': {'count': 1, 'than': 1},
#  'skill,': {'count': 1, 'vault': 1},
#  'small': {'count': 1, 'number': 1},
#  'so': {'count': 4, 'on.': 2, 'the': 2},
#  'some': {'count': 1, 'evidence': 1},
#  'specificity': {'%0': 1, 'count': 2, 'or': 1},
#  'specifics': {'count': 1, 'of': 1},
#  'speed': {'between': 1, 'count': 1},
#  'spends': {'count': 1, 'under': 1},
#  'sport': {'count': 3, 'research': 1, 'science,': 1, 'specificity': 1},
#  'sports': {'%0': 1, 'count': 3, 'drinks,': 1, 'in': 1},
#  'sports.': {'A': 1, 'count': 1},
#  'sportsci.org/jour/9901/fch.html': {'(762': 1, 'count': 1},
#  'sportsci.org/jour/9901/lmb.html': {'(1733': 1, 'count': 1},
#  'sportsci.org/jour/9901/med.html': {'(1559': 1, 'count': 1},
#  'sportsci.org/jour/9901/mt23.html': {'%D': 1, 'count': 1},
#  'sportsci.org/jour/9901/rbk.html': {'(5579': 1, 'count': 1},
#  'sportsci.org/jour/9901/rmn.html': {'(768': 1, 'count': 1},
#  'sportsci.org/jour/9901/was.html': {'(865': 1, 'count': 1},
#  'sportsci.org/jour/9901/wghedit.html': {'(721': 1, 'count': 1},
#  'sportsci.org/jour/9901/wghnews.html': {'(1101': 1, 'count': 1},
#  'sportsci.org/jour/9901/wghpaper.html': {'(1805': 1, 'count': 1},
#  'sportsci.org/jour/9901/wghreview.html': {'(2618': 1, 'count': 1},
#  'sportsci.org/jour/9901/wghstyle.html': {'(4397': 1, 'count': 1},
#  'sportsci.org/news/history/atwater/atwater.html': {'%D': 1, 'count': 1},
#  'stages': {'count': 1, 'involved': 1},
#  'standard': {'count': 1, 'deviations': 1},
#  'statistical': {'count': 1, 'procedures': 1},
#  'statistics,': {'count': 1, 'sections': 1},
#  'status': {'and': 1, 'count': 1},
#  'steady-state': {'count': 1, 'fluid': 1},
#  'stimulating': {'count': 1, 'the': 1},
#  'strategies': {'count': 2, 'during': 1, 'on': 1},
#  'strength': {'and': 1, 'by': 1, 'count': 4, 'training': 2},
#  'strength-training': {'count': 1, 'machine': 1},
#  'stress.': {'Whether': 1, 'count': 1},
#  'structures': {'count': 1, 'for': 1},
#  'studies': {'count': 3, 'indicate': 1, 'may': 1, 'that': 1},
#  'studies.': {'Until': 1, 'count': 1},
#  'study': {'count': 1, 'is': 1},
#  'study.': {'ANALYSES.': 1, 'count': 1},
#  'study;': {'count': 1, 'list': 1},
#  'studying': {'animals': 1, 'count': 1},
#  'style': {'count': 2, 'for': 1, 'promoted': 1},
#  'style,': {'count': 1, 'ranging': 1},
#  'subjects,': {'count': 1, 'their': 1},
#  'subtle': {'count': 1, 'differences': 1},
#  'successfully': {'count': 1, 'increased': 1},
#  'summary': {'count': 4, 'must': 2, 'only': 2},
#  'supplementation': {'count': 4, 'may': 1, 'of': 2, 'on': 1},
#  'supplementation,': {'count': 1, 'team': 1},
#  'supplements': {'count': 3, 'is': 1, 'reviewed': 1, 'taken': 1},
#  'suppression,': {'but': 1, 'count': 1},
#  'surface': {'count': 1, 'waves.': 1},
#  'surfaces': {'count': 1, 'creates': 1},
#  'swim,': {'count': 1, 'thrust': 1},
#  'swimmers': {'%J': 1, 'count': 3, 'should': 1, 'the': 1},
#  'swimmers.': {'In': 1, 'count': 1},
#  'swimming.': {'The': 1, 'count': 1},
#  'system': {'count': 1, 'for': 1},
#  'taken': {'by': 1, 'count': 1},
#  'targeted': {'count': 1, 'muscle': 1},
#  'taught': {'count': 1, 'progressively,': 1},
#  'teaching': {'conferences,': 1, 'count': 1},
#  'teaching.': {'%K': 1, 'count': 1},
#  'team': {'count': 4, 'game': 1, 'games': 1, 'games:': 1, 'sports': 1},
#  'team-sport': {'athletes': 1, 'count': 1},
#  'tempered': {'by': 1, 'count': 1},
#  'templates,': {'count': 1, 'reprints,': 1},
#  'tests,': {'count': 2, 'research': 1, 'simulated': 1},
#  'than': {'300': 2, 'count': 5, 'drag.': 1, 'other': 1, 'researchers': 1},
#  'that': {'certain': 1,
#   'count': 11,
#   'creatine': 1,
#   'for': 1,
#   'lift': 1,
#   'minimizes': 1,
#   'move': 1,
#   'necessary': 1,
#   'power': 1,
#   'supplementation': 1,
#   'the': 1,
#   'unsteady': 1},
#  'the': {'American': 1,
#   'Sportscience': 1,
#   'Summary': 1,
#   'Summary,': 1,
#   'advice': 1,
#   'air-water': 1,
#   "athlete's": 1,
#   'athlete.': 1,
#   'chance': 1,
#   'compulsory': 1,
#   'count': 69,
#   'dependent': 1,
#   'depth': 1,
#   'differentiation': 1,
#   'document.': 1,
#   'documents': 2,
#   'effect': 2,
#   'effects': 1,
#   'elements': 1,
#   'exercise': 1,
#   'field,': 1,
#   'first': 1,
#   'flow': 1,
#   'fluid': 1,
#   'glide': 1,
#   'greatest': 1,
#   'grounds': 1,
#   'main': 2,
#   'means': 1,
#   'measurement': 1,
#   'most': 1,
#   'movement': 1,
#   'nature': 1,
#   'need': 1,
#   'number': 1,
#   'nutrients': 1,
#   'nutritional': 1,
#   'objective': 1,
#   'ongoing': 1,
#   'optimal': 1,
#   'other': 1,
#   'outcomes': 2,
#   'pace': 1,
#   'potential': 1,
#   'power': 3,
#   'precision': 1,
#   "reader's": 1,
#   'relationship': 1,
#   'release': 1,
#   'review.': 2,
#   'specifics': 1,
#   'stages': 1,
#   'statistical': 1,
#   'style': 1,
#   'subtle': 1,
#   'theoretical': 1,
#   'thrust-generating': 2,
#   'time': 1,
#   'top': 1,
#   'training': 1,
#   'true': 1,
#   'user': 1},
#  'their': {'appropriate': 1,
#   'athletic': 1,
#   'count': 5,
#   'ergogenic': 1,
#   'estimates': 1,
#   'findings,': 1},
#  'them': {'count': 1, 'quantitatively,': 1},
#  'theoretical': {'count': 1, 'rationale': 1},
#  'there': {'are': 1, 'count': 2, 'is': 1},
#  'therefore': {'count': 1, 'publish': 1},
#  'these': {'amino': 1,
#   'count': 4,
#   'sports.': 1,
#   'strategies': 1,
#   'studies': 1},
#  'they': {'are': 1, 'count': 2, 'were': 1},
#  'think': {'count': 1, 'now': 1},
#  'this': {'article': 1,
#   'count': 6,
#   'first': 1,
#   'magnitude': 1,
#   'newsletter:': 1,
#   'summary': 2},
#  'those': {'count': 2, 'of': 1, 'who': 1},
#  'through': {'a': 1, 'count': 4, 'formal': 1, 'the': 1, 'to': 1},
#  'thrust': {'%0': 1, 'count': 3, 'generation': 1, 'than': 1},
#  'thrust,': {'count': 1, 'so': 1},
#  'thrust-generating': {'count': 2, 'mechanisms': 1, 'surfaces': 1},
#  'time': {'count': 2, 'each': 1, 'frame.': 1},
#  'timers,': {'and': 1, 'count': 1},
#  'to': {'be': 3,
#   'count': 28,
#   'decide': 1,
#   'develop': 1,
#   'enhance': 2,
#   'give': 1,
#   'have': 1,
#   'improve': 1,
#   'include': 1,
#   'instantly': 1,
#   'lack': 1,
#   'maintain': 1,
#   'measure': 2,
#   'or': 1,
#   'outline': 1,
#   'popular': 1,
#   'real': 1,
#   'reduce': 1,
#   'the': 4,
#   'training.': 1,
#   'write': 2},
#  'tools,': {'count': 1, 'those': 1},
#  'top': {'count': 1, 'of': 1},
#  'trainers': {'count': 1, 'preferred': 1},
#  'training': {'%0': 1,
#   '%J': 1,
#   'adaptations': 1,
#   'count': 5,
#   'enhances': 1,
#   'experience': 1},
#  'training.': {'FURTHER': 1, 'Supplementation': 1, 'count': 2},
#  'training;': {'as': 1, 'count': 1},
#  'trajectories': {'and': 1, 'count': 1},
#  'trial': {'count': 1, 'of': 1},
#  'trial,': {'and': 1, 'count': 1},
#  'true': {'count': 1, 'effects.': 1},
#  'two': {'count': 2, 'explaining': 1, 'sentences': 1},
#  'two.': {'Try': 1, 'count': 1},
#  'typical': {'between-event': 1, 'count': 1},
#  'uncertain,': {'because': 1, 'count': 1},
#  'under': {'count': 1, 'maximum': 1},
#  'unsteady': {'count': 2, 'fluid': 1, 'mechanisms': 1},
#  'untrained': {'count': 1, 'individuals': 1},
#  'unusual.': {'TECHNICALITIES.': 1, 'count': 1},
#  'use.': {'To': 1, 'count': 1},
#  'used': {'by': 1, 'count': 2, 'lab': 1},
#  'user': {'count': 1, 'to': 1},
#  'using': {'count': 1, 'video': 1},
#  'valine)': {'and': 1, 'count': 1},
#  'value': {'as': 1, 'count': 1},
#  'variables': {'count': 2, 'for': 2},
#  'variation': {'count': 1, 'in': 1},
#  'vault': {'%0': 1, 'by': 1, 'count': 2},
#  'video': {'count': 1, 'digitizing,': 1},
#  'view': {'count': 1, 'is': 1},
#  'vs': {'count': 1, 'the': 1},
#  'waves.': {'The': 1, 'count': 1},
#  'way': {'count': 1, 'to': 1},
#  'ways': {'count': 1, 'to': 1},
#  'weightlifting,': {'count': 1, 'power': 1},
#  'weights': {'count': 2, 'machine': 1, 'remains': 1},
#  'were': {'count': 1, 'unusual.': 1},
#  'what': {'count': 1, 'you': 1},
#  'when': {'count': 1, 'it': 1},
#  'who': {'count': 1, 'work': 1},
#  'why': {'count': 1, 'your': 1},
#  'will.hopkins=AT=otago.ac.nz': {'%O': 1, '%X': 4, 'count': 5},
#  'winning': {'count': 1, 'when': 1},
#  'with': {'a': 2,
#   'adequate': 1,
#   'biomechanics': 1,
#   'count': 15,
#   'due': 1,
#   'dynamically': 1,
#   'endurance': 1,
#   'hydroxymethylbutyrate': 1,
#   'likely': 1,
#   'presentation': 1,
#   'protein': 1,
#   'team-sport': 1,
#   'the': 1,
#   'words': 2},
#  'wmasands=AT=concentric.net': {'%X': 1, 'count': 1},
#  'words': {'as': 2, 'count': 2},
#  'words)': {'%D': 11, 'count': 11},
#  'words.': {'Be': 2, 'count': 2},
#  'work': {'by': 1, 'count': 3, 'on': 1, 'with': 1},
#  'worthwhile': {'count': 1, 'performance': 1},
#  'write': {'a': 2, 'count': 2},
#  'writing': {'%0': 2, '%J': 1, 'count': 3},
#  'yet': {'clear.': 1, 'count': 1},
#  'yet,': {'count': 1, 'limited': 1},
#  'you': {'count': 3, 'included': 1, 'reviewed.': 1, 'think': 1},
#  'your': {'count': 1, 'study': 1}}

# %%
def recommend_next_word(words_stats , word):
  # if the word is found in the dataset
  if word in words_stats:
    # get total of time word was found in the dataset
    total_count = words_stats[word]['count']
    print(word, " was found in the dataset with a total of ", total_count)

    # init holding variables for the final recommendation
    max_prob = 0
    next_word = None
    # iterate through all potential next word
    for key,value in words_stats[word].items():
      if key != 'count':
        probability = value / total_count
        #print(key, value, probability, max_prob)
        # if I find a next word with a higher probability
        # then save it
        if probability > max_prob:
          max_prob = probability
          next_word = key

    return next_word, max_prob
  else:
    print(word, " is not found in the dataset")
    return None, None

# %%
next_word, prob = recommend_next_word(words_stats, 'of')
print(next_word, prob)
# Out:
# of  was found in the dataset with a total of  73
# the 0.1095890410958904

# %%
words_stats['of']
# Out:
# {'25': 1,
#  'Exercise': 3,
#  'Human': 2,
#  'Management,': 1,
#  'Massachusetts,': 1,
#  'Memphis,': 1,
#  'Otago,': 6,
#  'Physical': 5,
#  'Physiology': 4,
#  'Physiology,': 1,
#  'Sport,': 2,
#  'Sports': 2,
#  'Utah,': 1,
#  'X': 1,
#  'an': 1,
#  'consistency': 1,
#  'count': 73,
#  'data,': 1,
#  'effects.': 1,
#  'growth': 1,
#  'hydration': 1,
#  'ideas': 1,
#  'intermittent': 1,
#  'less': 2,
#  'motion;': 1,
#  'nutritional': 1,
#  'performance': 1,
#  'performance,': 1,
#  'practical': 1,
#  'precision': 1,
#  'protein': 2,
#  'protein,': 1,
#  'publications.': 1,
#  'punctuation': 1,
#  'researchers': 1,
#  'scientific': 1,
#  'sport': 1,
#  'subjects,': 1,
#  'teaching.': 1,
#  'the': 8,
#  'their': 3,
#  'these': 2,
#  'this': 1,
#  'thrust': 1,
#  'winning': 1}

# %%
alx = {}
print(id(alx))
alx = {1,2,3}
print(id(alx))
# Out:
# 2105268613760
# 2105267228000
